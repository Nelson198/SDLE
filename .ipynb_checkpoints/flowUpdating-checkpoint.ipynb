# %%
import random
import matplotlib.pyplot as plt
import networkx as nx
import heapq as hq

# %%
def completeGraph(nVertices):
    # Initialize the graph
    G = nx.Graph()

    # Add nodes
    G.add_nodes_from(range(nVertices))

    # List all possible edges
    edges = list(nx.non_edges(G))
    random.shuffle(edges)
    while not nx.is_connected(G):
        x, y = edges.pop()
        G.add_edge(x, y)

    return G

# %%
def drawGraph(G):
    plt.figure(figsize = (12,8), dpi = 50)
    nx.draw_networkx(G,
                     with_labels = True,
                     style = "solid",
                     node_size = 700,
                     node_color = "orange",
                     font_size = 14,
                     font_color = "black",
                     font_weight = "bold")
    plt.show()

# %%
G = completeGraph(10)
drawGraph(G)

# %%
class FlowUpdatingBroad:
    def __init__(self, neighbors, inputValue, timeout):
        self.timeout = timeout
        self.messages = []
        self.neighbors = neighbors
        self.f = {}
        self.e = {}
        for n in neighbors:
            self.f[n] = 0
            self.e[n] = 0
        self.v = inputValue

    def gen_message(self):
        messages = [("TIMEOUT", self.timeout, True)]
        for n in self.neighbors:
            msg = (self.f[n], self.e[n])
            messages.append(("FLOW", (n, msg)))
        return messages

    def calculateEstimate(self):
        sumF = 0
        sumE = 0
        for n in self.neighbors:
            sumF += self.f[n]
            sumE += self.e[n]
        return (self.v - sumF + sumE) / (len(self.neighbors) + 1)

    def state_transition(self):
        for m in self.messages:
            src = m[0]
            (f, e) = m[1]
            self.f[src] = -f
            self.e[src] = e

        newE = self.calculateEstimate()
        
        stop = True
        for n in self.neighbors:
            if abs(round(newE, 3) - round(self.e[self.k], 3)) > 0.001:
                stop = False
            
            self.f[n] += newE - self.e[n]
            self.e[n] = newE
            
        return stop


    def handle(self, src, msg):
        if msg == "INITIAL":
            return self.gen_message()
        else:
            if msg[0] == "FLOW":
                self.messages.append((src, msg[1]))
            else: # timeout message, end of round
                if not self.state_transition():
                    return self.gen_message()
        return []

# %%
class FlowUpdatingUni:
    def __init__(self, neighbors, inputValue, timeout):
        self.timeout = timeout
        self.messages = []
        self.neighbors = neighbors
        self.f = {}
        self.e = {}
        self.k = self.chooseNeighbor()
        for n in neighbors:
            self.f[n] = 0
            self.e[n] = 0
        self.v = inputValue
        
    def chooseNeighbor(self):
        return random.choice(list(self.neighbors))

    def gen_message(self):
        messages = [("TIMEOUT", self.timeout, True)]
        msg = (self.f[self.k], self.e[self.k])
        messages.append(("FLOW", (self.k, msg)))
        return messages

    def calculateEstimate(self):
        sumF = 0
        sumE = 0
        for n in self.neighbors:
            sumF += self.f[n]
            sumE += self.e[n]
        return (self.v - sumF + sumE) / (len(self.neighbors) + 1)

    def state_transition(self):
        for m in self.messages:
            src = m[0]
            (f, e) = m[1]
            self.f[src] = -f
            self.e[src] = e

        newE = self.calculateEstimate()
        print(round(newE, 2), round(self.e[self.k], 2))
        
        stop = False
        if abs(round(newE, 2) - round(self.e[self.k], 2)) <= 0.05:
            stop = True
            
        self.k = self.chooseNeighbor()
        
        self.f[self.k] += newE - self.e[self.k]
        self.e[self.k] = newE
        
        return stop

    def handle(self, src, msg):
        if msg == "INITIAL":
            return self.gen_message()
        else:
            if msg[0] == "FLOW":
                self.messages.append((src, msg[1]))
            else: # timeout message, end of round
                if not self.state_transition():
                    return self.gen_message()
                else:
                    return [("TIMEOUT", self.timeout, True)]
        return []

# %%
class Simulator:
    def __init__(self, nodes, distances, faultProbability, viewChange, timeout):
        self.nodes = nodes
        self.distances = distances
        self.currentTime = 0
        self.pending = [] # [(delay, (src, dest, msg))]
        self.faultProbability = faultProbability
        self.viewChange = viewChange
        self.timeout = timeout

    def start(self):
        for n in self.nodes:
            event = (0, (None, n, "INITIAL"))
            hq.heappush(self.pending, event)

        # Add first view change
        if self.viewChange != -1:
            hq.heappush(self.pending, (self.viewChange, (float("+infinity"), None, "VIEWCHANGE")))

        return self.runLoop()

    def runLoop(self):
        flag = True
        sent_messages = len(self.pending)
        while len(self.pending) != 0:
            if len(self.pending) == 1:
                (delay, (src, dest, msg)) = self.pending[0]
                if msg != "VIEWCHANGE":
                    break

            (delay, (src, dest, msg)) = hq.heappop(self.pending)
            print(dest, "received", msg, "from", src, "at", delay)
            self.currentTime = delay
            
            if (self.currentTime % self.timeout) == 0 and self.currentTime != 0:
                if flag:
                    break

            # Message to change the view
            if msg == "VIEWCHANGE":
                print("View changing...")

                vc = (self.currentTime + self.viewChange, (float("+infinity"), None, "VIEWCHANGE"))
                print("VIEWCHANGE", vc)
                hq.heappush(self.pending, vc)

                newGraph = completeGraph(len(self.nodes))
                drawGraph(newGraph)
                self.distances, self.nodes = newNeighborsAndDistances(newGraph, self.nodes, random.randrange(10), False)
                continue

            # Message between two nodes or a timeout
            newEvents = self.nodes[dest].handle(src, msg)

            if newEvents:
                #sent_messages += len(newEvents)
                for x in newEvents:
                    if x[0] != "TIMEOUT":
                        flag = False
                        sent_messages += 1
                        (msgType, (newMsgDest, newMsg)) = x
                        if self.faultProbability != 0 and random.randrange(round(1/self.faultProbability)) == 0: # fault-injection mechanism
                            print("Dropped", newMsg, "from", dest, "to", newMsgDest)
                            continue
                        dist = 0
                        if (dest, newMsgDest) not in self.distances and (newMsgDest, dest) not in self.distances:
                            print("Dropped one message from", dest, "to", newMsgDest, "because they are no longer neighbors")
                            continue
                        if dest < newMsgDest:
                            dist = self.distances[(dest, newMsgDest)]
                        else:
                            dist = self.distances[(newMsgDest, dest)]

                        ev = (self.currentTime + dist, (dest, newMsgDest, (msgType, newMsg)))
                        hq.heappush(self.pending, ev)
                    else:
                        (msgType, timeout, newMsg) = x
                        ev = (self.currentTime + timeout, (dest, dest, (msgType, timeout, newMsg)))
                        hq.heappush(self.pending, ev)
                        
        print()
        return sent_messages, (self.currentTime / self.timeout)

# %%
def newNeighborsAndDistances(G, nodes, flag, timeout):
    distances = {}
    for node in G.nodes():
        neighbors = set(G.neighbors(node))
        if flag:
            nodes[node] = FlowUpdatingUni(neighbors, 5, timeout)
        else:
            nodes[node].change_neighbors(neighbors)

        for neighbor in neighbors:
            if node < neighbor:
                distances[(node, neighbor)] = 1 # rand.randrange(10)
            else:
                distances[(neighbor, node)] = 1 # rand.randrange(10)

    return distances, nodes

# %%
def main():
    N = 5 # number of rounds
    fanout = 1
    messages_sent = 0
    rounds = 0
    timeout = 3
    max_rounds = float("-infinity")
    min_rounds = float("+infinity")

    for i in range(N):
        distances, nodes = newNeighborsAndDistances(G, {}, True, timeout)

        fp = 0 # fault-probability - probability for a message to be lost
        vcp = -1  # view-change periodicity - every vcp seconds, the set of neighbors change
        sim = Simulator(nodes, distances, fp, vcp, timeout)
        x, y = sim.start()
        messages_sent += x
        rounds += y

        if y > max_rounds:
            max_rounds = y
        if y < min_rounds:
            min_rounds = y

    print("Average rounds:", float(rounds / N))
    print("Average messages sent:", float(messages_sent / N))
    print("Min rounds:", min_rounds)
    print("Max rounds:", max_rounds)

# %%
main()
# Out:
# 0 received INITIAL from None at 0
# 1 received INITIAL from None at 0
# 2 received INITIAL from None at 0
# 3 received INITIAL from None at 0
# 4 received INITIAL from None at 0
# 5 received INITIAL from None at 0
# 6 received INITIAL from None at 0
# 7 received INITIAL from None at 0
# 8 received INITIAL from None at 0
# 9 received INITIAL from None at 0
# 3 received ('FLOW', (0, 0)) from 0 at 1
# 8 received ('FLOW', (0, 0)) from 1 at 1
# 0 received ('FLOW', (0, 0)) from 2 at 1
# 0 received ('FLOW', (0, 0)) from 3 at 1
# 7 received ('FLOW', (0, 0)) from 4 at 1
# 7 received ('FLOW', (0, 0)) from 5 at 1
# 3 received ('FLOW', (0, 0)) from 6 at 1
# 5 received ('FLOW', (0, 0)) from 7 at 1
# 1 received ('FLOW', (0, 0)) from 8 at 1
# 1 received ('FLOW', (0, 0)) from 9 at 1
# 0 received ('TIMEOUT', 3, True) from 0 at 3
# 1.25 0
# 1 received ('TIMEOUT', 3, True) from 1 at 3
# 1.0 0
# 2 received ('TIMEOUT', 3, True) from 2 at 3
# 1.25 0
# 3 received ('TIMEOUT', 3, True) from 3 at 3
# 1.25 0
# 4 received ('TIMEOUT', 3, True) from 4 at 3
# 1.67 0
# 5 received ('TIMEOUT', 3, True) from 5 at 3
# 1.67 0
# 6 received ('TIMEOUT', 3, True) from 6 at 3
# 2.5 0
# 7 received ('TIMEOUT', 3, True) from 7 at 3
# 1.25 0
# 8 received ('TIMEOUT', 3, True) from 8 at 3
# 1.67 0
# 9 received ('TIMEOUT', 3, True) from 9 at 3
# 2.5 0
# 7 received ('FLOW', (1.25, 1.25)) from 0 at 4
# 8 received ('FLOW', (1.0, 1.0)) from 1 at 4
# 1 received ('FLOW', (1.25, 1.25)) from 2 at 4
# 1 received ('FLOW', (1.25, 1.25)) from 3 at 4
# 7 received ('FLOW', (1.6666666666666667, 1.6666666666666667)) from 4 at 4
# 8 received ('FLOW', (1.6666666666666667, 1.6666666666666667)) from 5 at 4
# 3 received ('FLOW', (2.5, 2.5)) from 6 at 4
# 0 received ('FLOW', (1.25, 1.25)) from 7 at 4
# 1 received ('FLOW', (1.6666666666666667, 1.6666666666666667)) from 8 at 4
# 1 received ('FLOW', (2.5, 2.5)) from 9 at 4
# 0 received ('TIMEOUT', 3, True) from 0 at 6
# 1.88 1.25
# 1 received ('TIMEOUT', 3, True) from 1 at 6
# 3.67 1.67
# 2 received ('TIMEOUT', 3, True) from 2 at 6
# 1.25 1.25
# 3 received ('TIMEOUT', 3, True) from 3 at 6
# 2.5 1.25
# 4 received ('TIMEOUT', 3, True) from 4 at 6
# 1.67 1.67
# 5 received ('TIMEOUT', 3, True) from 5 at 6
# 1.67 1.67
# 6 received ('TIMEOUT', 3, True) from 6 at 6
# 2.5 2.5
# 7 received ('TIMEOUT', 3, True) from 7 at 6
# 2.71 1.25
# 8 received ('TIMEOUT', 3, True) from 8 at 6
# 3.44 1.0
# 9 received ('TIMEOUT', 3, True) from 9 at 6
# 2.5 2.5
# 3 received ('FLOW', (1.875, 1.875)) from 0 at 7
# 2 received ('FLOW', (1.166666666666667, 3.666666666666667)) from 1 at 7
# 6 received ('FLOW', (-2.5, 2.5)) from 3 at 7
# 0 received ('FLOW', (0.20833333333333348, 2.7083333333333335)) from 7 at 7
# 1 received ('FLOW', (1.4444444444444446, 3.4444444444444446)) from 8 at 7
# 0 received ('TIMEOUT', 3, True) from 0 at 9
# 1.98 0
# 1 received ('TIMEOUT', 3, True) from 1 at 9
# 3.98 1.25
# 2 received ('TIMEOUT', 3, True) from 2 at 9
# 2.46 1.25
# 3 received ('TIMEOUT', 3, True) from 3 at 9
# 3.44 2.5
# 4 received ('TIMEOUT', 3, True) from 4 at 9
# 1.67 1.67
# 5 received ('TIMEOUT', 3, True) from 5 at 9
# 1.67 1.67
# 6 received ('TIMEOUT', 3, True) from 6 at 9
# 2.5 2.5
# 7 received ('TIMEOUT', 3, True) from 7 at 9
# 2.71 1.25
# 8 received ('TIMEOUT', 3, True) from 8 at 9
# 3.44 1.0
# 9 received ('TIMEOUT', 3, True) from 9 at 9
# 2.5 2.5
# 7 received ('FLOW', (-0.9375, 1.979166666666667)) from 0 at 10
# 9 received ('FLOW', (-1.0222222222222221, 3.977777777777778)) from 1 at 10
# 0 received ('FLOW', (2.4583333333333335, 2.4583333333333335)) from 2 at 10
# 0 received ('FLOW', (-0.3125, 3.4375)) from 3 at 10
# 0 received ('FLOW', (0.20833333333333348, 2.7083333333333335)) from 7 at 10
# 1 received ('FLOW', (1.4444444444444446, 3.4444444444444446)) from 8 at 10
# 0 received ('TIMEOUT', 3, True) from 0 at 12
# 3.99 2.71
# 1 received ('TIMEOUT', 3, True) from 1 at 12
# 3.98 2.5
# 2 received ('TIMEOUT', 3, True) from 2 at 12
# 2.46 2.46
# 3 received ('TIMEOUT', 3, True) from 3 at 12
# 3.44 1.88
# 4 received ('TIMEOUT', 3, True) from 4 at 12
# 1.67 1.67
# 5 received ('TIMEOUT', 3, True) from 5 at 12
# 1.67 1.67
# 6 received ('TIMEOUT', 3, True) from 6 at 12
# 2.5 2.5
# 7 received ('TIMEOUT', 3, True) from 7 at 12
# 2.34 1.98
# 8 received ('TIMEOUT', 3, True) from 8 at 12
# 3.44 1.0
# 9 received ('TIMEOUT', 3, True) from 9 at 12
# 3.98 3.98
# 3 received ('FLOW', (0.8645833333333339, 3.989583333333334)) from 0 at 13
# 8 received ('FLOW', (-0.9111111111111114, 3.977777777777778)) from 1 at 13
# 0 received ('FLOW', (-0.3125, 3.4375)) from 3 at 13
# 5 received ('FLOW', (2.34375, 2.34375)) from 7 at 13
# 5 received ('FLOW', (0.11111111111111116, 3.4444444444444446)) from 8 at 13
# 0 received ('TIMEOUT', 3, True) from 0 at 15
# 3.99 3.44
# 1 received ('TIMEOUT', 3, True) from 1 at 15
# 3.98 3.44
# 2 received ('TIMEOUT', 3, True) from 2 at 15
# 2.46 3.67
# 3 received ('TIMEOUT', 3, True) from 3 at 15
# 3.71 3.99
# 4 received ('TIMEOUT', 3, True) from 4 at 15
# 1.67 1.67
# 5 received ('TIMEOUT', 3, True) from 5 at 15
# 4.41 2.34
# 6 received ('TIMEOUT', 3, True) from 6 at 15
# 2.5 2.5
# 7 received ('TIMEOUT', 3, True) from 7 at 15
# 2.34 0
# 8 received ('TIMEOUT', 3, True) from 8 at 15
# 3.8 1.67
# 9 received ('TIMEOUT', 3, True) from 9 at 15
# 3.98 3.98
# 7 received ('FLOW', (1.072916666666667, 3.989583333333334)) from 0 at 16
# 2 received ('FLOW', (1.4777777777777779, 3.977777777777778)) from 1 at 16
# 4 received ('FLOW', (2.4583333333333335, 2.4583333333333335)) from 2 at 16
# 0 received ('FLOW', (-1.1406250000000009, 3.713541666666667)) from 3 at 16
# 8 received ('FLOW', (0.8587962962962963, 4.414351851851852)) from 5 at 16
# 0 received ('FLOW', (1.302083333333333, 2.34375)) from 7 at 16
# 5 received ('FLOW', (0.466666666666667, 3.8000000000000003)) from 8 at 16
# 0 received ('TIMEOUT', 3, True) from 0 at 18
# 4.03 2.34
# 1 received ('TIMEOUT', 3, True) from 1 at 18
# 3.98 1.25
# 2 received ('TIMEOUT', 3, True) from 2 at 18
# 2.61 2.46
# 3 received ('TIMEOUT', 3, True) from 3 at 18
# 3.71 3.99
# 4 received ('TIMEOUT', 3, True) from 4 at 18
# 3.31 2.46
# 5 received ('TIMEOUT', 3, True) from 5 at 18
# 4.65 3.8
# 6 received ('TIMEOUT', 3, True) from 6 at 18
# 2.5 2.5
# 7 received ('TIMEOUT', 3, True) from 7 at 18
# 3.35 3.99
# 8 received ('TIMEOUT', 3, True) from 8 at 18
# 4.45 4.41
# 9 received ('TIMEOUT', 3, True) from 9 at 18
# 3.98 3.98
# 2 received ('FLOW', (-0.8828125000000009, 4.033854166666666)) from 0 at 19
# 9 received ('FLOW', (-1.0222222222222221, 3.977777777777778)) from 1 at 19
# 0 received ('FLOW', (2.613888888888889, 2.613888888888889)) from 2 at 19
# 6 received ('FLOW', (-1.286458333333333, 3.713541666666667)) from 3 at 19
# 7 received ('FLOW', (3.305555555555556, 3.305555555555556)) from 4 at 19
# 8 received ('FLOW', (0.3847222222222222, 4.6513888888888895)) from 5 at 19
# 5 received ('FLOW', (3.348958333333334, 3.348958333333334)) from 7 at 19
# 0 received ('TIMEOUT', 3, True) from 0 at 21
# 4.11 2.61
# 1 received ('TIMEOUT', 3, True) from 1 at 21
# 3.98 2.5
# 2 received ('TIMEOUT', 3, True) from 2 at 21
# 3.4 4.03
# 3 received ('TIMEOUT', 3, True) from 3 at 21
# 3.71 2.5
# 4 received ('TIMEOUT', 3, True) from 4 at 21
# 3.31 3.31
# 5 received ('TIMEOUT', 3, True) from 5 at 21
# 5.32 3.8
# 6 received ('TIMEOUT', 3, True) from 6 at 21
# 3.71 3.71
# 7 received ('TIMEOUT', 3, True) from 7 at 21
# 4.17 0
# 8 received ('TIMEOUT', 3, True) from 8 at 21
# 4.37 4.65
# 9 received ('TIMEOUT', 3, True) from 9 at 21
# 3.98 3.98
# 3 received ('FLOW', (1.5387152777777775, 4.111631944444444)) from 0 at 22
# 3 received ('FLOW', (1.4777777777777779, 3.977777777777778)) from 1 at 22
# 1 received ('FLOW', (-2.0539062500000003, 3.4016493055555554)) from 2 at 22
# 1 received ('FLOW', (3.713541666666667, 3.713541666666667)) from 3 at 22
# 7 received ('FLOW', (-1.376388888888889, 5.321527777777779)) from 5 at 22
# 4 received ('FLOW', (-2.442708333333333, 4.168402777777779)) from 7 at 22
# 5 received ('FLOW', (-0.6685185185185187, 4.367592592592593)) from 8 at 22
# 0 received ('TIMEOUT', 3, True) from 0 at 24
# 4.11 3.71
# 1 received ('TIMEOUT', 3, True) from 1 at 24
# 4.73 3.71
# 2 received ('TIMEOUT', 3, True) from 2 at 24
# 3.4 3.98
# 3 received ('TIMEOUT', 3, True) from 3 at 24
# 5.28 3.98
# 4 received ('TIMEOUT', 3, True) from 4 at 24
# 3.88 4.17
# 5 received ('TIMEOUT', 3, True) from 5 at 24
# 5.13 3.35
# 6 received ('TIMEOUT', 3, True) from 6 at 24
# 3.71 3.71
# 7 received ('TIMEOUT', 3, True) from 7 at 24
# 5.15 3.31
# 8 received ('TIMEOUT', 3, True) from 8 at 24
# 4.37 4.65
# 9 received ('TIMEOUT', 3, True) from 9 at 24
# 3.98 3.98
# 2 received ('FLOW', (-1.1161458333333343, 4.111631944444444)) from 0 at 25
# 9 received ('FLOW', (-0.26725694444444503, 4.732743055555555)) from 1 at 25
# 0 received ('FLOW', (0.25060763888889026, 3.4016493055555554)) from 2 at 25
# 0 received ('FLOW', (-0.37387152777777644, 5.276475694444445)) from 3 at 25
# 7 received ('FLOW', (2.155092592592592, 3.8807870370370376)) from 4 at 25
# 7 received ('FLOW', (-1.565586419753087, 5.132330246913581)) from 5 at 25
# 5 received ('FLOW', (1.209548611111111, 5.1546875000000005)) from 7 at 25
# 5 received ('FLOW', (-0.6685185185185187, 4.367592592592593)) from 8 at 25
# 0 received ('TIMEOUT', 3, True) from 0 at 27
# 4.3 3.4
# 1 received ('TIMEOUT', 3, True) from 1 at 27
# 4.73 2.5
# 2 received ('TIMEOUT', 3, True) from 2 at 27
# 3.36 4.11
# 3 received ('TIMEOUT', 3, True) from 3 at 27
# 5.28 4.11
# 4 received ('TIMEOUT', 3, True) from 4 at 27
# 3.88 4.17
# 5 received ('TIMEOUT', 3, True) from 5 at 27
# 5.02 5.15
# 6 received ('TIMEOUT', 3, True) from 6 at 27
# 3.71 3.71
# 7 received ('TIMEOUT', 3, True) from 7 at 27
# 4.92 5.13
# 8 received ('TIMEOUT', 3, True) from 8 at 27
# 4.37 4.65
# 9 received ('TIMEOUT', 3, True) from 9 at 27
# 4.73 4.73
# 7 received ('FLOW', (0.654340277777778, 4.300173611111111)) from 0 at 28
# 8 received ('FLOW', (-0.15614583333333432, 4.732743055555555)) from 1 at 28
# 4 received ('FLOW', (3.3627604166666663, 3.3627604166666663)) from 2 at 28
# 0 received ('FLOW', (-0.37387152777777644, 5.276475694444445)) from 3 at 28
# 2 received ('FLOW', (-1.0358796296296293, 3.8807870370370376)) from 4 at 28
# 8 received ('FLOW', (1.3220293209876541, 5.021103395061728)) from 5 at 28
# 4 received ('FLOW', (-1.119598765432098, 4.916280864197532)) from 7 at 28
# 5 received ('FLOW', (-0.6685185185185187, 4.367592592592593)) from 8 at 28
# 0 received ('TIMEOUT', 3, True) from 0 at 30
# 4.3 2.34
# 1 received ('TIMEOUT', 3, True) from 1 at 30
# 4.73 3.44
# 2 received ('TIMEOUT', 3, True) from 2 at 30
# 4.07 3.88
# 3 received ('TIMEOUT', 3, True) from 3 at 30
# 5.28 4.11
# 4 received ('TIMEOUT', 3, True) from 4 at 30
# 5.17 3.36
# 5 received ('TIMEOUT', 3, True) from 5 at 30
# 5.02 4.37
# 6 received ('TIMEOUT', 3, True) from 6 at 30
# 3.71 3.71
# 7 received ('TIMEOUT', 3, True) from 7 at 30
# 4.89 3.88
# 8 received ('TIMEOUT', 3, True) from 8 at 30
# 5.31 5.02
# 9 received ('TIMEOUT', 3, True) from 9 at 30
# 4.73 4.73
# 7 received ('FLOW', (0.654340277777778, 4.300173611111111)) from 0 at 31
# 3 received ('FLOW', (-2.694340277777779, 4.732743055555555)) from 1 at 31
# 4 received ('FLOW', (1.22907986111111, 4.073987268518518)) from 2 at 31
# 6 received ('FLOW', (0.27647569444444464, 5.276475694444445)) from 3 at 31
# 7 received ('FLOW', (1.3773855452674892, 5.174067644032923)) from 4 at 31
# 7 received ('FLOW', (-1.3431327160493831, 5.021103395061728)) from 5 at 31
# 4 received ('FLOW', (-1.1465952932098764, 4.889284336419753)) from 7 at 31
# 1 received ('FLOW', (0.7299794238683139, 5.306576646090535)) from 8 at 31
# 0 received ('TIMEOUT', 3, True) from 0 at 33
# 4.3 2.34
# 1 received ('TIMEOUT', 3, True) from 1 at 33
# 4.96 3.71
# 2 received ('TIMEOUT', 3, True) from 2 at 33
# 4.07 3.88
# 3 received ('TIMEOUT', 3, True) from 3 at 33
# 4.42 2.5
# 4 received ('TIMEOUT', 3, True) from 4 at 33
# 4.68 4.89
# 5 received ('TIMEOUT', 3, True) from 5 at 33
# 5.02 5.15
# 6 received ('TIMEOUT', 3, True) from 6 at 33
# 5.28 5.28
# 7 received ('TIMEOUT', 3, True) from 7 at 33
# 5.05 5.17
# 8 received ('TIMEOUT', 3, True) from 8 at 33
# 5.31 4.73
# 9 received ('TIMEOUT', 3, True) from 9 at 33
# 4.73 4.73
# 3 received ('FLOW', (-0.6024305555555571, 4.300173611111111)) from 0 at 34
# 9 received ('FLOW', (-0.03772350823045212, 4.962276491769548)) from 1 at 34
# 1 received ('FLOW', (-1.3815682870370374, 4.073987268518518)) from 2 at 34
# 1 received ('FLOW', (2.3837847222222237, 4.4221875)) from 3 at 34
# 2 received ('FLOW', (-0.6211484053497935, 4.681918724279835)) from 4 at 34
# 7 received ('FLOW', (-1.3431327160493831, 5.021103395061728)) from 5 at 34
# 4 received ('FLOW', (-1.5054687500000004, 5.045984439300412)) from 7 at 34
# 1 received ('FLOW', (0.7299794238683139, 5.306576646090535)) from 8 at 34
# 0 received ('TIMEOUT', 3, True) from 0 at 36
# 4.3 5.28
# 1 received ('TIMEOUT', 3, True) from 1 at 36
# 5.11 2.5
# 2 received ('TIMEOUT', 3, True) from 2 at 36
# 4.38 3.98
# 3 received ('TIMEOUT', 3, True) from 3 at 36
# 3.93 4.73
# 4 received ('TIMEOUT', 3, True) from 4 at 36
# 4.61 4.07
# 5 received ('TIMEOUT', 3, True) from 5 at 36
# 5.02 5.15
# 6 received ('TIMEOUT', 3, True) from 6 at 36
# 5.28 5.28
# 7 received ('TIMEOUT', 3, True) from 7 at 36
# 5.05 5.17
# 8 received ('TIMEOUT', 3, True) from 8 at 36
# 5.31 4.73
# 9 received ('TIMEOUT', 3, True) from 9 at 36
# 4.96 4.96
# 7 received ('FLOW', (0.654340277777778, 4.300173611111111)) from 0 at 37
# 9 received ('FLOW', (0.10698945473251076, 5.106989454732511)) from 1 at 37
# 1 received ('FLOW', (-1.0776025591563787, 4.377952996399177)) from 2 at 37
# 6 received ('FLOW', (-1.065963541666668, 3.934036458333332)) from 3 at 37
# 2 received ('FLOW', (-0.6885395233196148, 4.614527606310014)) from 4 at 37
# 7 received ('FLOW', (-1.3431327160493831, 5.021103395061728)) from 5 at 37
# 4 received ('FLOW', (-1.5054687500000004, 5.045984439300412)) from 7 at 37
# 5 received ('FLOW', (-1.0365560699588479, 5.306576646090535)) from 8 at 37
# 0 received ('TIMEOUT', 3, True) from 0 at 39
# 4.3 2.34
# 1 received ('TIMEOUT', 3, True) from 1 at 39
# 5.23 2.5
# 2 received ('TIMEOUT', 3, True) from 2 at 39
# 4.34 3.98
# 3 received ('TIMEOUT', 3, True) from 3 at 39
# 3.93 2.5
# 4 received ('TIMEOUT', 3, True) from 4 at 39
# 4.61 4.07
# 5 received ('TIMEOUT', 3, True) from 5 at 39
# 5.21 5.15
# 6 received ('TIMEOUT', 3, True) from 6 at 39
# 3.93 3.93
# 7 received ('TIMEOUT', 3, True) from 7 at 39
# 5.05 5.17
# 8 received ('TIMEOUT', 3, True) from 8 at 39
# 5.31 5.02
# 9 received ('TIMEOUT', 3, True) from 9 at 39
# 5.11 5.11
# 7 received ('FLOW', (0.654340277777778, 4.300173611111111)) from 0 at 40
# 2 received ('FLOW', (1.9282253086419754, 5.228575745884774)) from 1 at 40
# 4 received ('FLOW', (0.4182693544238667, 4.3442574374142655)) from 2 at 40
# 6 received ('FLOW', (-1.065963541666668, 3.934036458333332)) from 3 at 40
# 7 received ('FLOW', (1.074011917009602, 4.614527606310014)) from 4 at 40
# 8 received ('FLOW', (0.941398319615913, 5.2114188957476)) from 5 at 40
# 4 received ('FLOW', (-1.5054687500000004, 5.045984439300412)) from 7 at 40
# 1 received ('FLOW', (0.7299794238683139, 5.306576646090535)) from 8 at 40
# 0 received ('TIMEOUT', 3, True) from 0 at 42
# 4.3 2.34
# 1 received ('TIMEOUT', 3, True) from 1 at 42
# 5.23 4.38
# 2 received ('TIMEOUT', 3, True) from 2 at 42
# 4.77 4.61
# 3 received ('TIMEOUT', 3, True) from 3 at 42
# 3.93 2.5
# 4 received ('TIMEOUT', 3, True) from 4 at 42
# 4.43 5.05
# 5 received ('TIMEOUT', 3, True) from 5 at 42
# 5.21 5.31
# 6 received ('TIMEOUT', 3, True) from 6 at 42
# 3.93 3.93
# 7 received ('TIMEOUT', 3, True) from 7 at 42
# 4.83 4.61
# 8 received ('TIMEOUT', 3, True) from 8 at 42
# 5.24 4.73
# 9 received ('TIMEOUT', 3, True) from 9 at 42
# 5.11 5.11
# 7 received ('FLOW', (0.654340277777778, 4.300173611111111)) from 0 at 43
# 3 received ('FLOW', (-1.5773964763374497, 5.228575745884774)) from 1 at 43
# 1 received ('FLOW', (-2.3872322423696843, 4.769568812157065)) from 2 at 43
# 0 received ('FLOW', (0.2362934027777781, 3.934036458333332)) from 3 at 43
# 2 received ('FLOW', (-0.328179298125284, 4.434347493712848)) from 4 at 43
# 7 received ('FLOW', (-1.1528172153635117, 5.2114188957476)) from 5 at 43
# 0 received ('FLOW', (-0.12425786608367595, 4.830256022805213)) from 7 at 43
# 1 received ('FLOW', (0.6665409236396904, 5.243138145861911)) from 8 at 43
# 0 received ('TIMEOUT', 3, True) from 0 at 45
# 4.38 4.83
# 1 received ('TIMEOUT', 3, True) from 1 at 45
# 5.02 4.42
# 2 received ('TIMEOUT', 3, True) from 2 at 45
# 4.81 5.23
# 3 received ('TIMEOUT', 3, True) from 3 at 45
# 4.34 4.3
# 4 received ('TIMEOUT', 3, True) from 4 at 45
# 4.43 4.34
# 5 received ('TIMEOUT', 3, True) from 5 at 45
# 5.21 5.15
# 6 received ('TIMEOUT', 3, True) from 6 at 45
# 3.93 3.93
# 7 received ('TIMEOUT', 3, True) from 7 at 45
# 4.93 4.3
# 8 received ('TIMEOUT', 3, True) from 8 at 45
# 5.24 4.73
# 9 received ('TIMEOUT', 3, True) from 9 at 45
# 5.11 5.11
# 3 received ('FLOW', (0.21181637945816334, 4.3821462405692735)) from 0 at 46
# 9 received ('FLOW', (0.01959757230224035, 5.01959757230224)) from 1 at 46
# 1 received ('FLOW', (-2.3421872142203934, 4.814613840306356)) from 2 at 46
# 2 received ('FLOW', (-0.328179298125284, 4.434347493712848)) from 4 at 46
# 7 received ('FLOW', (-1.1528172153635117, 5.2114188957476)) from 5 at 46
# 4 received ('FLOW', (-0.7631257501714677, 4.925413773148148)) from 7 at 46
# 5 received ('FLOW', (-0.9096790695016017, 5.243138145861911)) from 8 at 46
# 0 received ('TIMEOUT', 3, True) from 0 at 48
# 4.38 3.93
# 1 received ('TIMEOUT', 3, True) from 1 at 48
# 5.04 2.5
# 2 received ('TIMEOUT', 3, True) from 2 at 48
# 4.81 5.23
# 3 received ('TIMEOUT', 3, True) from 3 at 48
# 4.56 4.38
# 4 received ('TIMEOUT', 3, True) from 4 at 48
# 4.64 4.34
# 5 received ('TIMEOUT', 3, True) from 5 at 48
# 5.23 5.15
# 6 received ('TIMEOUT', 3, True) from 6 at 48
# 3.93 3.93
# 7 received ('TIMEOUT', 3, True) from 7 at 48
# 4.93 4.61
# 8 received ('TIMEOUT', 3, True) from 8 at 48
# 5.24 5.21
# 9 received ('TIMEOUT', 3, True) from 9 at 48
# 5.02 5.02
# 2 received ('FLOW', (0.7298892961248278, 4.3821462405692735)) from 0 at 49
# 3 received ('FLOW', (-1.7683566386602667, 5.037615583561957)) from 1 at 49
# 1 received ('FLOW', (-2.3421872142203934, 4.814613840306356)) from 2 at 49
# 0 received ('FLOW', (-0.03267714763374663, 4.56128547239369)) from 3 at 49
# 2 received ('FLOW', (-0.12092185356652774, 4.6416049382716045)) from 4 at 49
# 7 received ('FLOW', (-1.131671048620638, 5.232565062490473)) from 5 at 49
# 0 received ('FLOW', (-0.029100115740741117, 4.925413773148148)) from 7 at 49
# 0 received ('TIMEOUT', 3, True) from 0 at 51
# 4.52 3.4
# 1 received ('TIMEOUT', 3, True) from 1 at 51
# 5.04 4.42
# 2 received ('TIMEOUT', 3, True) from 2 at 51
# 5.45 5.23
# 3 received ('TIMEOUT', 3, True) from 3 at 51
# 4.47 4.38
# 4 received ('TIMEOUT', 3, True) from 4 at 51
# 4.64 4.34
# 5 received ('TIMEOUT', 3, True) from 5 at 51
# 5.23 5.15
# 6 received ('TIMEOUT', 3, True) from 6 at 51
# 3.93 3.93
# 7 received ('TIMEOUT', 3, True) from 7 at 51
# 4.94 4.3
# 8 received ('TIMEOUT', 3, True) from 8 at 51
# 5.24 4.73
# 9 received ('TIMEOUT', 3, True) from 9 at 51
# 5.02 5.02
# 7 received ('FLOW', (-0.3770189257544576, 4.519294731652949)) from 0 at 52
# 8 received ('FLOW', (-0.8720634859396448, 5.037615583561957)) from 1 at 52
# 4 received ('FLOW', (0.926696834276405, 5.447379918981482)) from 2 at 52
# 1 received ('FLOW', (1.1965464463305917, 4.465805391232282)) from 3 at 52
# 2 received ('FLOW', (-0.12092185356652774, 4.6416049382716045)) from 4 at 52
# 8 received ('FLOW', (0.899105986130164, 5.232565062490473)) from 5 at 52
# 0 received ('FLOW', (-0.018527032369304308, 4.935986856519585)) from 7 at 52
# 5 received ('FLOW', (-0.9096790695016017, 5.243138145861911)) from 8 at 52
# 0 received ('TIMEOUT', 3, True) from 0 at 54
# 4.52 4.94
# 1 received ('TIMEOUT', 3, True) from 1 at 54
# 4.81 5.24
# 2 received ('TIMEOUT', 3, True) from 2 at 54
# 5.45 4.64
# 3 received ('TIMEOUT', 3, True) from 3 at 54
# 4.47 5.04
# 4 received ('TIMEOUT', 3, True) from 4 at 54
# 5.18 5.45
# 5 received ('TIMEOUT', 3, True) from 5 at 54
# 5.23 5.24
# 6 received ('TIMEOUT', 3, True) from 6 at 54
# 3.93 3.93
# 7 received ('TIMEOUT', 3, True) from 7 at 54
# 4.73 4.52
# 8 received ('TIMEOUT', 3, True) from 8 at 54
# 5.1 5.23
# 9 received ('TIMEOUT', 3, True) from 9 at 54
# 5.02 5.02
# 3 received ('FLOW', (-0.004027051421275907, 4.524581273338668)) from 0 at 55
# 9 received ('FLOW', (-0.19110849336991187, 4.808891506630088)) from 1 at 55
# 4 received ('FLOW', (0.926696834276405, 5.447379918981482)) from 2 at 55
# 6 received ('FLOW', (-0.5341946087677183, 4.465805391232282)) from 3 at 55
# 7 received ('FLOW', (1.0165002357681754, 5.178788258744856)) from 4 at 55
# 4 received ('FLOW', (-0.9556121875476293, 4.732927335771986)) from 7 at 55
# 5 received ('FLOW', (-1.0325966665396547, 5.099074382080983)) from 8 at 55
# 0 received ('TIMEOUT', 3, True) from 0 at 57
# 4.52 4.56
# 1 received ('TIMEOUT', 3, True) from 1 at 57
# 4.81 2.5
# 2 received ('TIMEOUT', 3, True) from 2 at 57
# 5.45 4.64
# 3 received ('TIMEOUT', 3, True) from 3 at 57
# 4.45 2.5
# 4 received ('TIMEOUT', 3, True) from 4 at 57
# 5.05 4.73
# 5 received ('TIMEOUT', 3, True) from 5 at 57
# 5.14 5.15
# 6 received ('TIMEOUT', 3, True) from 6 at 57
# 4.47 4.47
# 7 received ('TIMEOUT', 3, True) from 7 at 57
# 4.86 5.18
# 8 received ('TIMEOUT', 3, True) from 8 at 57
# 5.1 5.23
# 9 received ('TIMEOUT', 3, True) from 9 at 57
# 4.81 4.81
# 8 received ('FLOW', (-1.1007875628715134, 4.808891506630088)) from 1 at 58
# 4 received ('FLOW', (0.926696834276405, 5.447379918981482)) from 2 at 58
# 6 received ('FLOW', (-0.55254670829523, 4.44745329170477)) from 3 at 58
# 2 received ('FLOW', (-1.3236127860971383, 5.0504639671607485)) from 4 at 58
# 5 received ('FLOW', (0.7587205647005035, 4.859614578570339)) from 7 at 58
# 5 received ('FLOW', (-1.0325966665396547, 5.099074382080983)) from 8 at 58
# 0 received ('TIMEOUT', 3, True) from 0 at 60
# 4.52 4.94
# 1 received ('TIMEOUT', 3, True) from 1 at 60
# 4.81 5.24
# 2 received ('TIMEOUT', 3, True) from 2 at 60
# 5.25 5.05
# 3 received ('TIMEOUT', 3, True) from 3 at 60
# 4.45 2.5
# 4 received ('TIMEOUT', 3, True) from 4 at 60
# 5.05 5.45
# 5 received ('TIMEOUT', 3, True) from 5 at 60
# 4.89 5.1
# 6 received ('TIMEOUT', 3, True) from 6 at 60
# 4.45 4.45
# 7 received ('TIMEOUT', 3, True) from 7 at 60
# 4.86 5.23
# 8 received ('TIMEOUT', 3, True) from 8 at 60
# 4.95 5.23
# 9 received ('TIMEOUT', 3, True) from 9 at 60
# 4.81 4.81
# 7 received ('FLOW', (-0.3928785508116128, 4.524581273338668)) from 0 at 61
# 3 received ('FLOW', (-0.8534603309327853, 4.808891506630088)) from 1 at 61
# 4 received ('FLOW', (1.5220707620075054, 5.248921943071116)) from 2 at 61
# 1 received ('FLOW', (1.17819434680308, 4.44745329170477)) from 3 at 61
# 2 received ('FLOW', (-1.3236127860971383, 5.0504639671607485)) from 4 at 61
# 8 received ('FLOW', (0.8284599040627294, 4.8949376196040575)) from 5 at 61
# 5 received ('FLOW', (0.7587205647005035, 4.859614578570339)) from 7 at 61
# 5 received ('FLOW', (-1.1850793844942331, 4.946591664126404)) from 8 at 61
# 0 received ('TIMEOUT', 3, True) from 0 at 63
# 4.52 4.94
# 1 received ('TIMEOUT', 3, True) from 1 at 63
# 4.8 4.45
# 2 received ('TIMEOUT', 3, True) from 2 at 63
# 5.25 5.05
# 3 received ('TIMEOUT', 3, True) from 3 at 63
# 4.62 4.81
# 4 received ('TIMEOUT', 3, True) from 4 at 63
# 5.18 5.25
# 5 received ('TIMEOUT', 3, True) from 5 at 63
# 4.79 4.95
# 6 received ('TIMEOUT', 3, True) from 6 at 63
# 4.45 4.45
# 7 received ('TIMEOUT', 3, True) from 7 at 63
# 4.86 5.23
# 8 received ('TIMEOUT', 3, True) from 8 at 63
# 4.81 4.89
# 9 received ('TIMEOUT', 3, True) from 9 at 63
# 4.81 4.81
# 2 received ('FLOW', (0.872324328894222, 4.524581273338668)) from 0 at 64
# 2 received ('FLOW', (2.329124040733121, 4.801550666819083)) from 1 at 64
# 1 received ('FLOW', (-1.9078791114556335, 5.248921943071116)) from 2 at 64
# 1 received ('FLOW', (0.6635651737063704, 4.618996349403673)) from 3 at 64
# 7 received ('FLOW', (1.4054541362099693, 5.182769284434326)) from 4 at 64
# 7 received ('FLOW', (-0.8250526689698381, 4.793282474301004)) from 5 at 64
# 0 received ('FLOW', (0.7252685852004257, 4.8569713077274805)) from 7 at 64
# 5 received ('FLOW', (-0.912897034525, 4.810500489141787)) from 8 at 64
# 0 received ('TIMEOUT', 3, True) from 0 at 66
# 4.69 3.4
# 1 received ('TIMEOUT', 3, True) from 1 at 66
# 4.91 5.25
# 2 received ('TIMEOUT', 3, True) from 2 at 66
# 5.31 4.8
# 3 received ('TIMEOUT', 3, True) from 3 at 66
# 4.62 4.81
# 4 received ('TIMEOUT', 3, True) from 4 at 66
# 5.18 4.73
# 5 received ('TIMEOUT', 3, True) from 5 at 66
# 4.84 4.86
# 6 received ('TIMEOUT', 3, True) from 6 at 66
# 4.45 4.45
# 7 received ('TIMEOUT', 3, True) from 7 at 66
# 4.92 4.52
# 8 received ('TIMEOUT', 3, True) from 8 at 66
# 4.81 4.89
# 9 received ('TIMEOUT', 3, True) from 9 at 66
# 4.81 4.81
# 7 received ('FLOW', (-0.8914636023948326, 4.690776290533074)) from 0 at 67
# 8 received ('FLOW', (-1.0030223846561759, 4.906656684845426)) from 1 at 67
# 4 received ('FLOW', (1.5867566916485654, 5.313607872712176)) from 2 at 67
# 0 received ('FLOW', (0.09844212748628145, 4.618996349403673)) from 3 at 67
# 7 received ('FLOW', (1.4054541362099693, 5.182769284434326)) from 4 at 67
# 4 received ('FLOW', (-1.6661844335186657, 4.92203898712563)) from 7 at 67
# 1 received ('FLOW', (1.102396545383212, 4.810500489141787)) from 8 at 67
# 0 received ('TIMEOUT', 3, True) from 0 at 69
# 4.74 4.86
# 1 received ('TIMEOUT', 3, True) from 1 at 69
# 4.91 4.81
# 2 received ('TIMEOUT', 3, True) from 2 at 69
# 5.31 5.05
# 3 received ('TIMEOUT', 3, True) from 3 at 69
# 4.62 4.52
# 4 received ('TIMEOUT', 3, True) from 4 at 69
# 5.05 4.92
# 5 received ('TIMEOUT', 3, True) from 5 at 69
# 4.84 4.86
# 6 received ('TIMEOUT', 3, True) from 6 at 69
# 4.45 4.45
# 7 received ('TIMEOUT', 3, True) from 7 at 69
# 4.84 5.18
# 8 received ('TIMEOUT', 3, True) from 8 at 69
# 4.88 4.91
# 9 received ('TIMEOUT', 3, True) from 9 at 69
# 4.81 4.81
# 7 received ('FLOW', (-0.8442560643623294, 4.737983828565577)) from 0 at 70
# 8 received ('FLOW', (-1.005596756674894, 4.907300277850105)) from 1 at 70
# 0 received ('FLOW', (-0.08329772952071401, 5.313607872712176)) from 2 at 70
# 1 received ('FLOW', (0.6635651737063704, 4.618996349403673)) from 3 at 70
# 2 received ('FLOW', (-1.8482915250381726, 5.052073039322568)) from 4 at 70
# 0 received ('FLOW', (1.0396287903901849, 4.838941478528426)) from 7 at 70
# 0 received ('TIMEOUT', 3, True) from 0 at 72
# 5.21 4.84
# 1 received ('TIMEOUT', 3, True) from 1 at 72
# 4.91 4.81
# 2 received ('TIMEOUT', 3, True) from 2 at 72
# 5.18 4.52
# 3 received ('TIMEOUT', 3, True) from 3 at 72
# 4.62 4.81
# 4 received ('TIMEOUT', 3, True) from 4 at 72
# 5.05 5.31
# 5 received ('TIMEOUT', 3, True) from 5 at 72
# 4.84 4.86
# 6 received ('TIMEOUT', 3, True) from 6 at 72
# 4.45 4.45
# 7 received ('TIMEOUT', 3, True) from 7 at 72
# 4.86 4.74
# 8 received ('TIMEOUT', 3, True) from 8 at 72
# 4.88 4.89
# 9 received ('TIMEOUT', 3, True) from 9 at 72
# 4.81 4.81
# 7 received ('FLOW', (-0.6719905466686038, 5.206579722250007)) from 0 at 73
# 9 received ('FLOW', (-0.09269972214989508, 4.907300277850105)) from 1 at 73
# 1 received ('FLOW', (-1.9478342515348324, 5.182840456017372)) from 2 at 73
# 0 received ('FLOW', (0.09844212748628145, 4.618996349403673)) from 3 at 73
# 2 received ('FLOW', (-1.8482915250381726, 5.052073039322568)) from 4 at 73
# 4 received ('FLOW', (-1.7256781730996176, 4.862545247544678)) from 7 at 73
# 0 received ('TIMEOUT', 3, True) from 0 at 75
# 5.21 4.84
# 1 received ('TIMEOUT', 3, True) from 1 at 75
# 4.89 2.5
# 2 received ('TIMEOUT', 3, True) from 2 at 75
# 5.18 4.8
# 3 received ('TIMEOUT', 3, True) from 3 at 75
# 4.62 4.52
# 4 received ('TIMEOUT', 3, True) from 4 at 75
# 5.01 5.31
# 5 received ('TIMEOUT', 3, True) from 5 at 75
# 4.84 4.81
# 6 received ('TIMEOUT', 3, True) from 6 at 75
# 4.45 4.45
# 7 received ('TIMEOUT', 3, True) from 7 at 75
# 5.02 5.18
# 8 received ('TIMEOUT', 3, True) from 8 at 75
# 4.88 4.91
# 9 received ('TIMEOUT', 3, True) from 9 at 75
# 4.91 4.91
# 3 received ('FLOW', (0.4891412453600523, 5.206579722250007)) from 0 at 76
# 9 received ('FLOW', (-0.11390704757648429, 4.886092952423516)) from 1 at 76
# 1 received ('FLOW', (-1.9478342515348324, 5.182840456017372)) from 2 at 76
# 6 received ('FLOW', (-0.3810036505963268, 4.618996349403673)) from 3 at 76
# 2 received ('FLOW', (-1.8879540180921408, 5.0124105462686)) from 4 at 76
# 0 received ('FLOW', (0.4881714248078133, 5.0227606003892165)) from 7 at 76
# 0 received ('TIMEOUT', 3, True) from 0 at 78
# 5.11 4.62
# 1 received ('TIMEOUT', 3, True) from 1 at 78
# 4.89 2.5
# 2 received ('TIMEOUT', 3, True) from 2 at 78
# 5.16 4.8
# 3 received ('TIMEOUT', 3, True) from 3 at 78
# 4.91 2.5
# 4 received ('TIMEOUT', 3, True) from 4 at 78
# 5.01 5.31
# 5 received ('TIMEOUT', 3, True) from 5 at 78
# 4.84 4.81
# 6 received ('TIMEOUT', 3, True) from 6 at 78
# 4.62 4.62
# 7 received ('TIMEOUT', 3, True) from 7 at 78
# 5.02 5.21
# 8 received ('TIMEOUT', 3, True) from 8 at 78
# 4.88 4.91
# 9 received ('TIMEOUT', 3, True) from 9 at 78
# 4.89 4.89
# 3 received ('FLOW', (0.3972316844296566, 5.114670161319611)) from 0 at 79
# 2 received ('FLOW', (1.651086747940976, 4.886092952423516)) from 1 at 79
# 0 received ('FLOW', (-0.2338963927425013, 5.163009209490388)) from 2 at 79
# 1 received ('FLOW', (0.9573568601295381, 4.912788035826841)) from 3 at 79
# 7 received ('FLOW', (1.8755434718235398, 5.0124105462686)) from 4 at 79
# 4 received ('FLOW', (-1.565462820255079, 5.0227606003892165)) from 7 at 79
# 0 received ('TIMEOUT', 3, True) from 0 at 81
# 5.04 4.62
# 1 received ('TIMEOUT', 3, True) from 1 at 81
# 5.0 5.18
# 2 received ('TIMEOUT', 3, True) from 2 at 81
# 5.01 4.52
# 3 received ('TIMEOUT', 3, True) from 3 at 81
# 4.87 4.81
# 4 received ('TIMEOUT', 3, True) from 4 at 81
# 5.12 5.02
# 5 received ('TIMEOUT', 3, True) from 5 at 81
# 4.84 4.86
# 6 received ('TIMEOUT', 3, True) from 6 at 81
# 4.62 4.62
# 7 received ('TIMEOUT', 3, True) from 7 at 81
# 5.1 5.01
# 8 received ('TIMEOUT', 3, True) from 8 at 81
# 4.88 4.91
# 9 received ('TIMEOUT', 3, True) from 9 at 81
# 4.89 4.89
# 2 received ('FLOW', (0.1102580129608306, 5.039370829708718)) from 0 at 82
# 8 received ('FLOW', (-0.9092874075322159, 5.003609626992783)) from 1 at 82
# 1 received ('FLOW', (-1.5225442426710316, 5.01463545769346)) from 2 at 82
# 1 received ('FLOW', (0.9114020796643398, 4.866833255361643)) from 3 at 82
# 7 received ('FLOW', (1.6619230013641548, 5.119220781498292)) from 4 at 82
# 4 received ('FLOW', (-1.7902607683409624, 5.0976932497511775)) from 7 at 82
# 0 received ('TIMEOUT', 3, True) from 0 at 84
# 5.04 5.16
# 1 received ('TIMEOUT', 3, True) from 1 at 84
# 5.04 4.81
# 2 received ('TIMEOUT', 3, True) from 2 at 84
# 4.95 4.89
# 3 received ('TIMEOUT', 3, True) from 3 at 84
# 4.87 4.81
# 4 received ('TIMEOUT', 3, True) from 4 at 84
# 5.07 5.1
# 5 received ('TIMEOUT', 3, True) from 5 at 84
# 4.84 4.81
# 6 received ('TIMEOUT', 3, True) from 6 at 84
# 4.62 4.62
# 7 received ('TIMEOUT', 3, True) from 7 at 84
# 5.07 5.12
# 8 received ('TIMEOUT', 3, True) from 8 at 84
# 4.94 4.89
# 9 received ('TIMEOUT', 3, True) from 9 at 84
# 4.89 4.89
# 3 received ('FLOW', (0.321932352818763, 5.039370829708718)) from 0 at 85
# 3 received ('FLOW', (-0.7415906181113012, 5.036644716914681)) from 1 at 85
# 0 received ('FLOW', (-0.19681257486692338, 4.952816267802625)) from 2 at 85
# 6 received ('FLOW', (-0.13316674463835732, 4.866833255361643)) from 3 at 85
# 5 received ('FLOW', (-0.7841576092910014, 4.9392399143757855)) from 8 at 85
# 0 received ('TIMEOUT', 3, True) from 0 at 87
# 5.0 4.62
# 1 received ('TIMEOUT', 3, True) from 1 at 87
# 5.04 4.87
# 2 received ('TIMEOUT', 3, True) from 2 at 87
# 4.95 5.04
# 3 received ('TIMEOUT', 3, True) from 3 at 87
# 4.91 2.5
# 4 received ('TIMEOUT', 3, True) from 4 at 87
# 5.07 5.31
# 5 received ('TIMEOUT', 3, True) from 5 at 87
# 4.92 4.86
# 6 received ('TIMEOUT', 3, True) from 6 at 87
# 4.87 4.87
# 7 received ('TIMEOUT', 3, True) from 7 at 87
# 5.07 4.79
# 8 received ('TIMEOUT', 3, True) from 8 at 87
# 4.94 4.89
# 9 received ('TIMEOUT', 3, True) from 9 at 87
# 4.89 4.89
# 3 received ('FLOW', (0.2786550718657166, 4.996093548755671)) from 0 at 88
# 8 received ('FLOW', (-0.8762523176103176, 5.036644716914681)) from 1 at 88
# 1 received ('FLOW', (-1.584363432561867, 4.952816267802625)) from 2 at 88
# 6 received ('FLOW', (-0.08591067966728438, 4.914089320332716)) from 3 at 88
# 7 received ('FLOW', (1.7618332005134372, 5.069265681923652)) from 4 at 88
# 8 received ('FLOW', (0.7693901777004248, 4.924472482785209)) from 5 at 88
# 0 received ('FLOW', (0.5364015153623507, 5.070990690943754)) from 7 at 88
# 5 received ('FLOW', (-0.7841576092910014, 4.9392399143757855)) from 8 at 88
# 0 received ('TIMEOUT', 3, True) from 0 at 90
# 5.02 4.62
# 1 received ('TIMEOUT', 3, True) from 1 at 90
# 5.01 4.81
# 2 received ('TIMEOUT', 3, True) from 2 at 90
# 4.95 4.89
# 3 received ('TIMEOUT', 3, True) from 3 at 90
# 4.89 2.5
# 4 received ('TIMEOUT', 3, True) from 4 at 90
# 5.07 5.1
# 5 received ('TIMEOUT', 3, True) from 5 at 90
# 4.92 4.94
# 6 received ('TIMEOUT', 3, True) from 6 at 90
# 4.91 4.91
# 7 received ('TIMEOUT', 3, True) from 7 at 90
# 5.08 5.21
# 8 received ('TIMEOUT', 3, True) from 8 at 90
# 4.95 4.92
# 9 received ('TIMEOUT', 3, True) from 9 at 90
# 4.89 4.89
# 3 received ('FLOW', (0.30277011714298574, 5.02020859403294)) from 0 at 91
# 8 received ('FLOW', (-0.9009799935666516, 5.011917040958347)) from 1 at 91
# 4 received ('FLOW', (1.8283597396261655, 4.952816267802625)) from 2 at 91
# 0 received ('FLOW', (-0.38229794076519585, 4.892450679856192)) from 3 at 91
# 4 received ('FLOW', (-1.747619416599675, 5.0834794658374145)) from 7 at 91
# 0 received ('TIMEOUT', 3, True) from 0 at 93
# 4.97 4.89
# 1 received ('TIMEOUT', 3, True) from 1 at 93
# 5.01 4.81
# 2 received ('TIMEOUT', 3, True) from 2 at 93
# 4.95 5.01
# 3 received ('TIMEOUT', 3, True) from 3 at 93
# 4.9 5.02
# 4 received ('TIMEOUT', 3, True) from 4 at 93
# 5.04 5.08
# 5 received ('TIMEOUT', 3, True) from 5 at 93
# 4.92 4.94
# 6 received ('TIMEOUT', 3, True) from 6 at 93
# 4.91 4.91
# 7 received ('TIMEOUT', 3, True) from 7 at 93
# 5.08 5.07
# 8 received ('TIMEOUT', 3, True) from 8 at 93
# 4.93 5.01
# 9 received ('TIMEOUT', 3, True) from 9 at 93
# 4.89 4.89
# 2 received ('FLOW', (0.2123834666474993, 4.968387159583201)) from 0 at 94
# 9 received ('FLOW', (0.011917040958347336, 5.011917040958347)) from 1 at 94
# 1 received ('FLOW', (-1.584363432561867, 4.952816267802625)) from 2 at 94
# 1 received ('FLOW', (0.609454103691446, 4.904508202494826)) from 3 at 94
# 1 received ('FLOW', (0.8239961885674143, 4.93493323595911)) from 8 at 94
# 0 received ('TIMEOUT', 3, True) from 0 at 96
# 4.97 4.95
# 1 received ('TIMEOUT', 3, True) from 1 at 96
# 4.93 2.5
# 2 received ('TIMEOUT', 3, True) from 2 at 96
# 4.96 4.89
# 3 received ('TIMEOUT', 3, True) from 3 at 96
# 4.9 5.04
# 4 received ('TIMEOUT', 3, True) from 4 at 96
# 5.04 4.95
# 5 received ('TIMEOUT', 3, True) from 5 at 96
# 4.92 4.86
# 6 received ('TIMEOUT', 3, True) from 6 at 96
# 4.91 4.91
# 7 received ('TIMEOUT', 3, True) from 7 at 96
# 5.08 4.79
# 8 received ('TIMEOUT', 3, True) from 8 at 96
# 4.93 5.01
# 9 received ('TIMEOUT', 3, True) from 9 at 96
# 5.01 5.01
# 9 received ('FLOW', (-0.07173108680928841, 4.928268913190712)) from 1 at 97
# 4 received ('FLOW', (1.836145185516454, 4.960601713692913)) from 2 at 97
# 0 received ('FLOW', (-0.41847050868110003, 4.904508202494826)) from 3 at 97
# 2 received ('FLOW', (-1.7421639885399474, 5.039012018888843)) from 4 at 97
# 8 received ('FLOW', (0.7693901777004248, 4.924472482785209)) from 5 at 97
# 5 received ('FLOW', (1.1152496605062483, 5.0834794658374145)) from 7 at 97
# 5 received ('FLOW', (-0.7589294245265237, 4.93493323595911)) from 8 at 97
# 0 received ('TIMEOUT', 3, True) from 0 at 99
# 4.96 4.9
# 1 received ('TIMEOUT', 3, True) from 1 at 99
# 4.93 2.5
# 2 received ('TIMEOUT', 3, True) from 2 at 99
# 5.0 5.04
# 3 received ('TIMEOUT', 3, True) from 3 at 99
# 4.9 5.02
# 4 received ('TIMEOUT', 3, True) from 4 at 99
# 5.04 4.96
# 5 received ('TIMEOUT', 3, True) from 5 at 99
# 5.12 4.93
# 6 received ('TIMEOUT', 3, True) from 6 at 99
# 4.91 4.91
# 7 received ('TIMEOUT', 3, True) from 7 at 99
# 5.08 4.79
# 8 received ('TIMEOUT', 3, True) from 8 at 99
# 4.93 4.92
# 9 received ('TIMEOUT', 3, True) from 9 at 99
# 4.93 4.93
# 3 received ('FLOW', (0.4763207044501572, 4.962358398263883)) from 0 at 100
# 2 received ('FLOW', (1.5598160779499537, 4.928268913190712)) from 1 at 100
# 0 received ('FLOW', (-0.41847050868110003, 4.904508202494826)) from 3 at 100
# 7 received ('FLOW', (1.7083422669112958, 5.044202316149035)) from 4 at 100
# 7 received ('FLOW', (-1.0738181470849133, 5.1249109792587495)) from 5 at 100
# 5 received ('FLOW', (1.1152496605062483, 5.0834794658374145)) from 7 at 100
# 0 received ('TIMEOUT', 3, True) from 0 at 102
# 4.96 4.9
# 1 received ('TIMEOUT', 3, True) from 1 at 102
# 4.93 4.95
# 2 received ('TIMEOUT', 3, True) from 2 at 102
# 4.99 4.97
# 3 received ('TIMEOUT', 3, True) from 3 at 102
# 4.93 4.96
# 4 received ('TIMEOUT', 3, True) from 4 at 102
# 5.04 5.08
# 5 received ('TIMEOUT', 3, True) from 5 at 102
# 5.12 5.08
# 6 received ('TIMEOUT', 3, True) from 6 at 102
# 4.91 4.91
# 7 received ('TIMEOUT', 3, True) from 7 at 102
# 5.08 5.12
# 8 received ('TIMEOUT', 3, True) from 8 at 102
# 4.93 4.92
# 9 received ('TIMEOUT', 3, True) from 9 at 102
# 4.93 4.93
# 2 received ('FLOW', (0.2063547053281818, 4.962358398263883)) from 0 at 103
# 0 received ('TIMEOUT', 3, True) from 0 at 105
# 4.96 4.95
# 1 received ('TIMEOUT', 3, True) from 1 at 105
# 4.93 4.9
# 2 received ('TIMEOUT', 3, True) from 2 at 105
# 4.99 4.96
# 3 received ('TIMEOUT', 3, True) from 3 at 105
# 4.93 5.04
# 4 received ('TIMEOUT', 3, True) from 4 at 105
# 5.04 5.08
# 5 received ('TIMEOUT', 3, True) from 5 at 105
# 5.12 4.93
# 6 received ('TIMEOUT', 3, True) from 6 at 105
# 4.91 4.91
# 7 received ('TIMEOUT', 3, True) from 7 at 105
# 5.08 5.04
# 8 received ('TIMEOUT', 3, True) from 8 at 105
# 4.93 4.92
# 9 received ('TIMEOUT', 3, True) from 9 at 105
# 4.93 4.93
# 0 received ('FLOW', (-0.5052458023346853, 4.933433300379355)) from 3 at 106
# 7 received ('FLOW', (-1.0738181470849133, 5.1249109792587495)) from 5 at 106
# 0 received ('TIMEOUT', 3, True) from 0 at 108
# 4.95 4.93
# 1 received ('TIMEOUT', 3, True) from 1 at 108
# 4.93 4.9
# 2 received ('TIMEOUT', 3, True) from 2 at 108
# 4.99 4.93
# 3 received ('TIMEOUT', 3, True) from 3 at 108
# 4.93 4.96
# 4 received ('TIMEOUT', 3, True) from 4 at 108
# 5.04 4.96
# 5 received ('TIMEOUT', 3, True) from 5 at 108
# 5.12 5.08
# 6 received ('TIMEOUT', 3, True) from 6 at 108
# 4.91 4.91
# 7 received ('TIMEOUT', 3, True) from 7 at 108
# 5.08 5.21
# 8 received ('TIMEOUT', 3, True) from 8 at 108
# 4.93 5.01
# 9 received ('TIMEOUT', 3, True) from 9 at 108
# 4.93 4.93
# 0 received ('FLOW', (-0.18030157232165855, 4.9884115312704065)) from 2 at 109
# 7 received ('FLOW', (1.7083422669112958, 5.044202316149035)) from 4 at 109
# 5 received ('FLOW', (1.0334638155300562, 5.084556647703892)) from 7 at 109
# 1 received ('FLOW', (0.8239961885674143, 4.93493323595911)) from 8 at 109
# 0 received ('TIMEOUT', 3, True) from 0 at 111
# 4.96 5.07
# 1 received ('TIMEOUT', 3, True) from 1 at 111
# 4.93 4.93
# 2 received ('TIMEOUT', 3, True) from 2 at 111
# 4.99 4.96
# 3 received ('TIMEOUT', 3, True) from 3 at 111
# 4.93 5.04
# 4 received ('TIMEOUT', 3, True) from 4 at 111
# 5.04 5.08
# 5 received ('TIMEOUT', 3, True) from 5 at 111
# 5.1 4.93
# 6 received ('TIMEOUT', 3, True) from 6 at 111
# 4.91 4.91
# 7 received ('TIMEOUT', 3, True) from 7 at 111
# 5.08 5.12
# 8 received ('TIMEOUT', 3, True) from 8 at 111
# 4.93 5.01
# 9 received ('TIMEOUT', 3, True) from 9 at 111
# 4.93 4.93
# 2 received ('FLOW', (0.15281245687613243, 4.96092241582488)) from 0 at 112
# 0 received ('FLOW', (-0.5052458023346853, 4.933433300379355)) from 3 at 112
# 8 received ('FLOW', (0.9220042801229253, 5.098008091555512)) from 5 at 112
# 1 received ('FLOW', (0.8239961885674143, 4.93493323595911)) from 8 at 112
# 0 received ('TIMEOUT', 3, True) from 0 at 114
# 4.96 4.99
# 1 received ('TIMEOUT', 3, True) from 1 at 114
# 4.93 4.9
# 2 received ('TIMEOUT', 3, True) from 2 at 114
# 4.97 4.96
# 3 received ('TIMEOUT', 3, True) from 3 at 114
# 4.93 4.96
# 4 received ('TIMEOUT', 3, True) from 4 at 114
# 5.04 5.08
# 5 received ('TIMEOUT', 3, True) from 5 at 114
# 5.1 4.93
# 6 received ('TIMEOUT', 3, True) from 6 at 114
# 4.91 4.91
# 7 received ('TIMEOUT', 3, True) from 7 at 114
# 5.08 5.12
# 8 received ('TIMEOUT', 3, True) from 8 at 114
# 5.04 5.01
# 9 received ('TIMEOUT', 3, True) from 9 at 114
# 4.93 4.93
# 7 received ('FLOW', (-1.0200123716784368, 5.098008091555512)) from 5 at 115
# 0 received ('TIMEOUT', 3, True) from 0 at 117
# 4.96 5.07
# 1 received ('TIMEOUT', 3, True) from 1 at 117
# 4.93 4.93
# 2 received ('TIMEOUT', 3, True) from 2 at 117
# 4.97 5.04
# 3 received ('TIMEOUT', 3, True) from 3 at 117
# 4.93 4.96
# 4 received ('TIMEOUT', 3, True) from 4 at 117
# 5.04 5.08
# 5 received ('TIMEOUT', 3, True) from 5 at 117
# 5.1 5.08
# 6 received ('TIMEOUT', 3, True) from 6 at 117
# 4.91 4.91
# 7 received ('TIMEOUT', 3, True) from 7 at 117
# 5.09 5.04
# 8 received ('TIMEOUT', 3, True) from 8 at 117
# 5.04 5.01
# 9 received ('TIMEOUT', 3, True) from 9 at 117
# 4.93 4.93
# 7 received ('FLOW', (-0.6464697904812242, 4.96092241582488)) from 0 at 118
# 0 received ('FLOW', (-0.13906789915336937, 4.974666973547643)) from 2 at 118
# 0 received ('TIMEOUT', 3, True) from 0 at 120
# 4.97 5.07
# 1 received ('TIMEOUT', 3, True) from 1 at 120
# 4.93 4.95
# 2 received ('TIMEOUT', 3, True) from 2 at 120
# 4.97 4.96
# 3 received ('TIMEOUT', 3, True) from 3 at 120
# 4.93 2.5
# 4 received ('TIMEOUT', 3, True) from 4 at 120
# 5.04 5.08
# 5 received ('TIMEOUT', 3, True) from 5 at 120
# 5.1 4.93
# 6 received ('TIMEOUT', 3, True) from 6 at 120
# 4.91 4.91
# 7 received ('TIMEOUT', 3, True) from 7 at 120
# 5.04 4.96
# 8 received ('TIMEOUT', 3, True) from 8 at 120
# 5.04 5.1
# 9 received ('TIMEOUT', 3, True) from 9 at 120
# 4.93 4.93
# 7 received ('FLOW', (-0.6395975116198427, 4.967794694686262)) from 0 at 121
# 0 received ('FLOW', (-0.5052458023346853, 4.933433300379355)) from 3 at 121
# 8 received ('FLOW', (0.9220042801229253, 5.098008091555512)) from 5 at 121
# 4 received ('FLOW', (-1.7162963509900653, 5.036248232070266)) from 7 at 121
# 5 received ('FLOW', (-0.9763625653217265, 5.043649806356711)) from 8 at 121
# 0 received ('TIMEOUT', 3, True) from 0 at 123
# 4.97 5.07
# 1 received ('TIMEOUT', 3, True) from 1 at 123
# 4.93 2.5
# 2 received ('TIMEOUT', 3, True) from 2 at 123
# 4.97 4.96
# 3 received ('TIMEOUT', 3, True) from 3 at 123
# 4.93 4.96
# 4 received ('TIMEOUT', 3, True) from 4 at 123
# 5.04 5.04
# 5 received ('TIMEOUT', 3, True) from 5 at 123
# 5.06 5.04
# 6 received ('TIMEOUT', 3, True) from 6 at 123
# 4.91 4.91
# 7 received ('TIMEOUT', 3, True) from 7 at 123
# 5.04 5.04
# 8 received ('TIMEOUT', 3, True) from 8 at 123
# 5.04 5.1
# 9 received ('TIMEOUT', 3, True) from 9 at 123
# 4.93 4.93
# 2 received ('FLOW', (0.13219562029198784, 4.967794694686262)) from 0 at 124
# 2 received ('FLOW', (1.5598160779499537, 4.928268913190712)) from 1 at 124
# 1 received ('FLOW', (0.9327127589650148, 5.043649806356711)) from 8 at 124
# 0 received ('TIMEOUT', 3, True) from 0 at 126
# 4.97 4.97
# 1 received ('TIMEOUT', 3, True) from 1 at 126
# 4.97 4.95
# 2 received ('TIMEOUT', 3, True) from 2 at 126
# 4.97 5.04
# 3 received ('TIMEOUT', 3, True) from 3 at 126
# 4.93 5.04
# 4 received ('TIMEOUT', 3, True) from 4 at 126
# 5.04 4.96
# 5 received ('TIMEOUT', 3, True) from 5 at 126
# 5.06 5.04
# 6 received ('TIMEOUT', 3, True) from 6 at 126
# 4.91 4.91
# 7 received ('TIMEOUT', 3, True) from 7 at 126
# 5.04 5.04
# 8 received ('TIMEOUT', 3, True) from 8 at 126
# 5.04 5.01
# 9 received ('TIMEOUT', 3, True) from 9 at 126
# 4.93 4.93
# 1 received ('FLOW', (-1.5168541570237126, 4.971230834116953)) from 2 at 127
# 1 received ('FLOW', (0.638379201575975, 4.933433300379355)) from 3 at 127
# 2 received ('FLOW', (-1.757847305779511, 5.038899593429856)) from 4 at 127
# 0 received ('TIMEOUT', 3, True) from 0 at 129
# 4.97 5.07
# 1 received ('TIMEOUT', 3, True) from 1 at 129
# 5.0 4.97
# 2 received ('TIMEOUT', 3, True) from 2 at 129
# 4.97 4.93
# 3 received ('TIMEOUT', 3, True) from 3 at 129
# 4.93 5.04
# 4 received ('TIMEOUT', 3, True) from 4 at 129
# 5.04 4.96
# 5 received ('TIMEOUT', 3, True) from 5 at 129
# 5.06 5.08
# 6 received ('TIMEOUT', 3, True) from 6 at 129
# 4.91 4.91
# 7 received ('TIMEOUT', 3, True) from 7 at 129
# 5.04 4.97
# 8 received ('TIMEOUT', 3, True) from 8 at 129
# 5.04 5.1
# 9 received ('TIMEOUT', 3, True) from 9 at 129
# 4.93 4.93
# 7 received ('FLOW', (-0.6395975116198427, 4.967794694686262)) from 0 at 130
# 1 received ('FLOW', (0.638379201575975, 4.933433300379355)) from 3 at 130
# 7 received ('FLOW', (1.7189477123496557, 5.038899593429856)) from 4 at 130
# 0 received ('FLOW', (0.7114871884345373, 5.0396843715009565)) from 7 at 130
# 1 received ('FLOW', (0.9327127589650148, 5.043649806356711)) from 8 at 130
# 0 received ('TIMEOUT', 3, True) from 0 at 132
# 5.0 5.04
# 1 received ('TIMEOUT', 3, True) from 1 at 132
# 5.0 2.5
# 2 received ('TIMEOUT', 3, True) from 2 at 132
# 4.97 5.04
# 3 received ('TIMEOUT', 3, True) from 3 at 132
# 4.93 5.04
# 4 received ('TIMEOUT', 3, True) from 4 at 132
# 5.04 5.04
# 5 received ('TIMEOUT', 3, True) from 5 at 132
# 5.06 5.04
# 6 received ('TIMEOUT', 3, True) from 6 at 132
# 4.91 4.91
# 7 received ('TIMEOUT', 3, True) from 7 at 132
# 5.04 4.97
# 8 received ('TIMEOUT', 3, True) from 8 at 132
# 5.04 5.01
# 9 received ('TIMEOUT', 3, True) from 9 at 132
# 4.93 4.93
# 2 received ('FLOW', (1.5461336717808196, 5.00051034887406)) from 1 at 133
# 4 received ('FLOW', (1.6862296107919699, 4.967281898442315)) from 2 at 133
# 0 received ('FLOW', (-0.5052458023346853, 4.933433300379355)) from 3 at 133
# 0 received ('FLOW', (0.712812869114333, 5.041010052180752)) from 7 at 133
# 0 received ('TIMEOUT', 3, True) from 0 at 135
# 5.0 4.93
# 1 received ('TIMEOUT', 3, True) from 1 at 135
# 5.0 4.97
# 2 received ('TIMEOUT', 3, True) from 2 at 135
# 4.98 5.04
# 3 received ('TIMEOUT', 3, True) from 3 at 135
# 4.93 4.96
# 4 received ('TIMEOUT', 3, True) from 4 at 135
# 4.99 5.04
# 5 received ('TIMEOUT', 3, True) from 5 at 135
# 5.06 5.04
# 6 received ('TIMEOUT', 3, True) from 6 at 135
# 4.91 4.91
# 7 received ('TIMEOUT', 3, True) from 7 at 135
# 5.04 4.97
# 8 received ('TIMEOUT', 3, True) from 8 at 135
# 5.04 5.01
# 9 received ('TIMEOUT', 3, True) from 9 at 135
# 4.93 4.93
# 3 received ('FLOW', (0.5762148753888372, 5.004402373433507)) from 0 at 136
# 0 received ('FLOW', (-0.11806865915738118, 4.9819216558208685)) from 2 at 136
# 4 received ('FLOW', (-1.7168372535987597, 5.041010052180752)) from 7 at 136
# 0 received ('TIMEOUT', 3, True) from 0 at 138
# 5.01 4.93
# 1 received ('TIMEOUT', 3, True) from 1 at 138
# 5.0 4.97
# 2 received ('TIMEOUT', 3, True) from 2 at 138
# 4.98 4.97
# 3 received ('TIMEOUT', 3, True) from 3 at 138
# 4.97 5.04
# 4 received ('TIMEOUT', 3, True) from 4 at 138
# 4.99 4.97
# 5 received ('TIMEOUT', 3, True) from 5 at 138
# 5.06 5.08
# 6 received ('TIMEOUT', 3, True) from 6 at 138
# 4.91 4.91
# 7 received ('TIMEOUT', 3, True) from 7 at 138
# 5.04 5.04
# 8 received ('TIMEOUT', 3, True) from 8 at 138
# 5.04 5.01
# 9 received ('TIMEOUT', 3, True) from 9 at 138
# 4.93 4.93
# 2 received ('FLOW', (0.14761285733732343, 5.011465854000811)) from 0 at 139
# 6 received ('FLOW', (-0.031082163093568482, 4.9689178369064315)) from 3 at 139
# 0 received ('TIMEOUT', 3, True) from 0 at 141
# 5.01 4.98
# 1 received ('TIMEOUT', 3, True) from 1 at 141
# 5.0 4.97
# 2 received ('TIMEOUT', 3, True) from 2 at 141
# 5.0 5.0
# 3 received ('TIMEOUT', 3, True) from 3 at 141
# 4.97 2.5
# 4 received ('TIMEOUT', 3, True) from 4 at 141
# 4.99 5.04
# 5 received ('TIMEOUT', 3, True) from 5 at 141
# 5.06 5.04
# 6 received ('TIMEOUT', 3, True) from 6 at 141
# 4.97 4.97
# 7 received ('TIMEOUT', 3, True) from 7 at 141
# 5.04 4.97
# 8 received ('TIMEOUT', 3, True) from 8 at 141
# 5.04 5.01
# 9 received ('TIMEOUT', 3, True) from 9 at 141
# 4.93 4.93
# 0 received ('FLOW', (-0.6116994119159127, 4.9689178369064315)) from 3 at 142
# 4 received ('FLOW', (-1.7168372535987597, 5.041010052180752)) from 7 at 142
# 0 received ('TIMEOUT', 3, True) from 0 at 144
# 4.99 4.97
# 1 received ('TIMEOUT', 3, True) from 1 at 144
# 5.0 2.5
# 2 received ('TIMEOUT', 3, True) from 2 at 144
# 5.0 5.01
# 3 received ('TIMEOUT', 3, True) from 3 at 144
# 4.97 5.0
# 4 received ('TIMEOUT', 3, True) from 4 at 144
# 4.99 4.97
# 5 received ('TIMEOUT', 3, True) from 5 at 144
# 5.06 5.04
# 6 received ('TIMEOUT', 3, True) from 6 at 144
# 4.97 4.97
# 7 received ('TIMEOUT', 3, True) from 7 at 144
# 5.04 5.04
# 8 received ('TIMEOUT', 3, True) from 8 at 144
# 5.04 5.1
# 9 received ('TIMEOUT', 3, True) from 9 at 144
# 4.93 4.93
# 2 received ('FLOW', (1.5461336717808196, 5.00051034887406)) from 1 at 145
# 5 received ('FLOW', (-0.9763625653217265, 5.043649806356711)) from 8 at 145
# 0 received ('TIMEOUT', 3, True) from 0 at 147
# 4.99 4.98
# 1 received ('TIMEOUT', 3, True) from 1 at 147
# 5.0 4.97
# 2 received ('TIMEOUT', 3, True) from 2 at 147
# 5.0 5.01
# 3 received ('TIMEOUT', 3, True) from 3 at 147
# 4.97 5.0
# 4 received ('TIMEOUT', 3, True) from 4 at 147
# 4.99 4.97
# 5 received ('TIMEOUT', 3, True) from 5 at 147
# 5.06 5.04
# 6 received ('TIMEOUT', 3, True) from 6 at 147
# 4.97 4.97
# 7 received ('TIMEOUT', 3, True) from 7 at 147
# 5.04 5.1
# 8 received ('TIMEOUT', 3, True) from 8 at 147
# 5.04 5.1
# 9 received ('TIMEOUT', 3, True) from 9 at 147
# 4.93 4.93
# 4 received ('FLOW', (-1.7168372535987597, 5.041010052180752)) from 7 at 148
# 1 received ('FLOW', (0.9327127589650148, 5.043649806356711)) from 8 at 148
# 0 received ('TIMEOUT', 3, True) from 0 at 150
# 4.99 5.04
# 1 received ('TIMEOUT', 3, True) from 1 at 150
# 5.0 5.04
# 2 received ('TIMEOUT', 3, True) from 2 at 150
# 5.0 5.04
# 3 received ('TIMEOUT', 3, True) from 3 at 150
# 4.97 2.5
# 4 received ('TIMEOUT', 3, True) from 4 at 150
# 4.99 5.04
# 5 received ('TIMEOUT', 3, True) from 5 at 150
# 5.06 5.04
# ...
# 4.99 5.04
# 5 received ('TIMEOUT', 3, True) from 5 at 975
# 5.0 5.01
# 6 received ('TIMEOUT', 3, True) from 6 at 975
# 5.01 5.01
# 7 received ('TIMEOUT', 3, True) from 7 at 975
# 5.04 4.97
# 8 received ('TIMEOUT', 3, True) from 8 at 975
# 5.01 5.01
# 9 received ('TIMEOUT', 3, True) from 9 at 975
# 5.01 5.01
# 5 received ('FLOW', (0.9630143323036773, 5.041010052180752)) from 7 at 976
# 0 received ('TIMEOUT', 3, True) from 0 at 978
# 5.01 5.04
# 1 received ('TIMEOUT', 3, True) from 1 at 978
# 5.01 4.97
# 2 received ('TIMEOUT', 3, True) from 2 at 978
# 5.0 5.04
# 3 received ('TIMEOUT', 3, True) from 3 at 978
# 5.01 2.5
# 4 received ('TIMEOUT', 3, True) from 4 at 978
# 4.99 4.97
# 5 received ('TIMEOUT', 3, True) from 5 at 978
# 5.0 5.04
# 6 received ('TIMEOUT', 3, True) from 6 at 978
# 5.01 5.01
# 7 received ('TIMEOUT', 3, True) from 7 at 978
# 5.04 5.1
# 8 received ('TIMEOUT', 3, True) from 8 at 978
# 5.01 5.1
# 9 received ('TIMEOUT', 3, True) from 9 at 978
# 5.01 5.01
# 6 received ('FLOW', (0.006875664339739629, 5.00687566433974)) from 3 at 979
# 4 received ('FLOW', (-1.7168372535987597, 5.041010052180752)) from 7 at 979
# 5 received ('FLOW', (-1.01313641483688, 5.006875956841557)) from 8 at 979
# 0 received ('TIMEOUT', 3, True) from 0 at 981
# 5.01 4.98
# 1 received ('TIMEOUT', 3, True) from 1 at 981
# 5.01 2.5
# 2 received ('TIMEOUT', 3, True) from 2 at 981
# 5.0 5.01
# 3 received ('TIMEOUT', 3, True) from 3 at 981
# 5.01 2.5
# 4 received ('TIMEOUT', 3, True) from 4 at 981
# 4.99 5.04
# 5 received ('TIMEOUT', 3, True) from 5 at 981
# 5.0 5.01
# 6 received ('TIMEOUT', 3, True) from 6 at 981
# 5.01 5.01
# 7 received ('TIMEOUT', 3, True) from 7 at 981
# 5.04 5.04
# 8 received ('TIMEOUT', 3, True) from 8 at 981
# 5.01 5.1
# 9 received ('TIMEOUT', 3, True) from 9 at 981
# 5.01 5.01
# 9 received ('FLOW', (0.006875844562857836, 5.006875844562858)) from 1 at 982
# 1 received ('FLOW', (0.5599902558031271, 5.00687566433974)) from 3 at 982
# 5 received ('FLOW', (-1.01313641483688, 5.006875956841557)) from 8 at 982
# 0 received ('TIMEOUT', 3, True) from 0 at 984
# 5.01 4.98
# 1 received ('TIMEOUT', 3, True) from 1 at 984
# 5.01 2.5
# 2 received ('TIMEOUT', 3, True) from 2 at 984
# 5.0 5.01
# 3 received ('TIMEOUT', 3, True) from 3 at 984
# 5.01 5.01
# 4 received ('TIMEOUT', 3, True) from 4 at 984
# 4.99 5.04
# 5 received ('TIMEOUT', 3, True) from 5 at 984
# 5.0 5.01
# 6 received ('TIMEOUT', 3, True) from 6 at 984
# 5.01 5.01
# 7 received ('TIMEOUT', 3, True) from 7 at 984
# 5.04 5.1
# 8 received ('TIMEOUT', 3, True) from 8 at 984
# 5.01 5.1
# 9 received ('TIMEOUT', 3, True) from 9 at 984
# 5.01 5.01
# 2 received ('FLOW', (1.5524991253213578, 5.006875802414598)) from 1 at 985
# 4 received ('FLOW', (-1.7168372535987597, 5.041010052180752)) from 7 at 985
# 1 received ('FLOW', (1.0062604579953218, 5.006875956841557)) from 8 at 985
# 0 received ('TIMEOUT', 3, True) from 0 at 987
# 5.01 5.01
# 1 received ('TIMEOUT', 3, True) from 1 at 987
# 5.01 4.97
# 2 received ('TIMEOUT', 3, True) from 2 at 987
# 5.0 5.04
# 3 received ('TIMEOUT', 3, True) from 3 at 987
# 5.01 5.0
# 4 received ('TIMEOUT', 3, True) from 4 at 987
# 4.99 4.97
# 5 received ('TIMEOUT', 3, True) from 5 at 987
# 5.0 5.01
# 6 received ('TIMEOUT', 3, True) from 6 at 987
# 5.01 5.01
# 7 received ('TIMEOUT', 3, True) from 7 at 987
# 5.04 5.04
# 8 received ('TIMEOUT', 3, True) from 8 at 987
# 5.01 5.01
# 9 received ('TIMEOUT', 3, True) from 9 at 987
# 5.01 5.01
# 0 received ('TIMEOUT', 3, True) from 0 at 990
# 5.01 4.98
# 1 received ('TIMEOUT', 3, True) from 1 at 990
# 5.01 5.01
# 2 received ('TIMEOUT', 3, True) from 2 at 990
# 5.0 5.04
# 3 received ('TIMEOUT', 3, True) from 3 at 990
# 5.01 5.01
# 4 received ('TIMEOUT', 3, True) from 4 at 990
# 4.99 4.97
# 5 received ('TIMEOUT', 3, True) from 5 at 990
# 5.0 5.01
# 6 received ('TIMEOUT', 3, True) from 6 at 990
# 5.01 5.01
# 7 received ('TIMEOUT', 3, True) from 7 at 990
# 5.04 4.97
# 8 received ('TIMEOUT', 3, True) from 8 at 990
# 5.01 5.01
# 9 received ('TIMEOUT', 3, True) from 9 at 990
# 5.01 5.01
# 4 received ('FLOW', (-1.7168372535987597, 5.041010052180752)) from 7 at 991
# 0 received ('TIMEOUT', 3, True) from 0 at 993
# 5.01 5.01
# 1 received ('TIMEOUT', 3, True) from 1 at 993
# 5.01 5.01
# 2 received ('TIMEOUT', 3, True) from 2 at 993
# 5.0 5.01
# 3 received ('TIMEOUT', 3, True) from 3 at 993
# 5.01 5.0
# 4 received ('TIMEOUT', 3, True) from 4 at 993
# 4.99 5.04
# 5 received ('TIMEOUT', 3, True) from 5 at 993
# 5.0 5.01
# 6 received ('TIMEOUT', 3, True) from 6 at 993
# 5.01 5.01
# 7 received ('TIMEOUT', 3, True) from 7 at 993
# 5.04 5.04
# 8 received ('TIMEOUT', 3, True) from 8 at 993
# 5.01 5.01
# 9 received ('TIMEOUT', 3, True) from 9 at 993
# 5.01 5.01
# 0 received ('TIMEOUT', 3, True) from 0 at 996
# 5.01 4.98
# 1 received ('TIMEOUT', 3, True) from 1 at 996
# 5.01 4.97
# 2 received ('TIMEOUT', 3, True) from 2 at 996
# 5.0 5.01
# 3 received ('TIMEOUT', 3, True) from 3 at 996
# 5.01 5.01
# 4 received ('TIMEOUT', 3, True) from 4 at 996
# 4.99 4.97
# 5 received ('TIMEOUT', 3, True) from 5 at 996
# 5.0 5.01
# 6 received ('TIMEOUT', 3, True) from 6 at 996
# 5.01 5.01
# 7 received ('TIMEOUT', 3, True) from 7 at 996
# 5.04 5.04
# 8 received ('TIMEOUT', 3, True) from 8 at 996
# 5.01 5.1
# 9 received ('TIMEOUT', 3, True) from 9 at 996
# 5.01 5.01
# 1 received ('FLOW', (1.0062604579953218, 5.006875956841557)) from 8 at 997
# 0 received ('TIMEOUT', 3, True) from 0 at 999
# 5.01 5.01
# 1 received ('TIMEOUT', 3, True) from 1 at 999
# 5.01 5.01
# 2 received ('TIMEOUT', 3, True) from 2 at 999
# 5.0 5.01
# 3 received ('TIMEOUT', 3, True) from 3 at 999
# 5.01 5.0
# 4 received ('TIMEOUT', 3, True) from 4 at 999
# 4.99 4.97
# 5 received ('TIMEOUT', 3, True) from 5 at 999
# 5.0 5.04
# 6 received ('TIMEOUT', 3, True) from 6 at 999
# 5.01 5.01
# 7 received ('TIMEOUT', 3, True) from 7 at 999
# 5.04 4.97
# 8 received ('TIMEOUT', 3, True) from 8 at 999
# 5.01 5.01
# 9 received ('TIMEOUT', 3, True) from 9 at 999
# 5.01 5.01
# 4 received ('FLOW', (-1.7168372535987597, 5.041010052180752)) from 7 at 1000
# 0 received ('TIMEOUT', 3, True) from 0 at 1002
# 5.01 5.01
# 1 received ('TIMEOUT', 3, True) from 1 at 1002
# 5.01 4.97
# 2 received ('TIMEOUT', 3, True) from 2 at 1002
# 5.0 5.04
# 3 received ('TIMEOUT', 3, True) from 3 at 1002
# 5.01 2.5
# 4 received ('TIMEOUT', 3, True) from 4 at 1002
# 4.99 4.97
# 5 received ('TIMEOUT', 3, True) from 5 at 1002
# 5.0 5.01
# 6 received ('TIMEOUT', 3, True) from 6 at 1002
# 5.01 5.01
# 7 received ('TIMEOUT', 3, True) from 7 at 1002
# 5.04 5.04
# 8 received ('TIMEOUT', 3, True) from 8 at 1002
# 5.01 5.1
# 9 received ('TIMEOUT', 3, True) from 9 at 1002
# 5.01 5.01
# 1 received ('FLOW', (0.5599902558031271, 5.00687566433974)) from 3 at 1003
# 5 received ('FLOW', (-1.01313641483688, 5.006875956841557)) from 8 at 1003
# 0 received ('TIMEOUT', 3, True) from 0 at 1005
# 5.01 5.04
# 1 received ('TIMEOUT', 3, True) from 1 at 1005
# 5.01 4.97
# 2 received ('TIMEOUT', 3, True) from 2 at 1005
# 5.0 5.01
# 3 received ('TIMEOUT', 3, True) from 3 at 1005
# 5.01 5.01
# 4 received ('TIMEOUT', 3, True) from 4 at 1005
# 4.99 4.97
# 5 received ('TIMEOUT', 3, True) from 5 at 1005
# 5.0 5.01
# 6 received ('TIMEOUT', 3, True) from 6 at 1005
# 5.01 5.01
# 7 received ('TIMEOUT', 3, True) from 7 at 1005
# 5.04 4.97
# 8 received ('TIMEOUT', 3, True) from 8 at 1005
# 5.01 5.1
# 9 received ('TIMEOUT', 3, True) from 9 at 1005
# 5.01 5.01
# 5 received ('FLOW', (0.9630143323036773, 5.041010052180752)) from 7 at 1006
# 5 received ('FLOW', (-1.01313641483688, 5.006875956841557)) from 8 at 1006
# 0 received ('TIMEOUT', 3, True) from 0 at 1008
# 5.01 4.98
# 1 received ('TIMEOUT', 3, True) from 1 at 1008
# 5.01 5.01
# 2 received ('TIMEOUT', 3, True) from 2 at 1008
# 5.0 5.01
# 3 received ('TIMEOUT', 3, True) from 3 at 1008
# 5.01 5.0
# 4 received ('TIMEOUT', 3, True) from 4 at 1008
# 4.99 4.97
# 5 received ('TIMEOUT', 3, True) from 5 at 1008
# 5.0 5.01
# 6 received ('TIMEOUT', 3, True) from 6 at 1008
# 5.01 5.01
# 7 received ('TIMEOUT', 3, True) from 7 at 1008
# 5.04 5.1
# 8 received ('TIMEOUT', 3, True) from 8 at 1008
# 5.01 5.1
# 9 received ('TIMEOUT', 3, True) from 9 at 1008
# 5.01 5.01
# 0 received ('FLOW', (0.712812869114333, 5.041010052180752)) from 7 at 1009
# 5 received ('FLOW', (-1.01313641483688, 5.006875956841557)) from 8 at 1009
# 0 received ('TIMEOUT', 3, True) from 0 at 1011
# 5.01 5.01
# 1 received ('TIMEOUT', 3, True) from 1 at 1011
# 5.01 5.01
# 2 received ('TIMEOUT', 3, True) from 2 at 1011
# 5.0 5.04
# 3 received ('TIMEOUT', 3, True) from 3 at 1011
# 5.01 2.5
# 4 received ('TIMEOUT', 3, True) from 4 at 1011
# 4.99 4.97
# 5 received ('TIMEOUT', 3, True) from 5 at 1011
# 5.0 5.04
# 6 received ('TIMEOUT', 3, True) from 6 at 1011
# 5.01 5.01
# 7 received ('TIMEOUT', 3, True) from 7 at 1011
# 5.04 4.97
# 8 received ('TIMEOUT', 3, True) from 8 at 1011
# 5.01 5.1
# 9 received ('TIMEOUT', 3, True) from 9 at 1011
# 5.01 5.01
# 0 received ('FLOW', (-0.5737415844826046, 5.00687566433974)) from 3 at 1012
# 4 received ('FLOW', (-1.7168372535987597, 5.041010052180752)) from 7 at 1012
# 5 received ('FLOW', (-1.01313641483688, 5.006875956841557)) from 8 at 1012
# 0 received ('TIMEOUT', 3, True) from 0 at 1014
# 5.01 5.01
# 1 received ('TIMEOUT', 3, True) from 1 at 1014
# 5.01 5.01
# 2 received ('TIMEOUT', 3, True) from 2 at 1014
# 5.0 5.04
# 3 received ('TIMEOUT', 3, True) from 3 at 1014
# 5.01 5.0
# 4 received ('TIMEOUT', 3, True) from 4 at 1014
# 4.99 4.97
# 5 received ('TIMEOUT', 3, True) from 5 at 1014
# 5.0 5.04
# 6 received ('TIMEOUT', 3, True) from 6 at 1014
# 5.01 5.01
# 7 received ('TIMEOUT', 3, True) from 7 at 1014
# 5.04 5.04
# 8 received ('TIMEOUT', 3, True) from 8 at 1014
# 5.01 5.1
# 9 received ('TIMEOUT', 3, True) from 9 at 1014
# 5.01 5.01
# 1 received ('FLOW', (1.0062604579953218, 5.006875956841557)) from 8 at 1015
# 0 received ('TIMEOUT', 3, True) from 0 at 1017
# 5.01 5.01
# 1 received ('TIMEOUT', 3, True) from 1 at 1017
# 5.01 2.5
# 2 received ('TIMEOUT', 3, True) from 2 at 1017
# 5.0 5.01
# 3 received ('TIMEOUT', 3, True) from 3 at 1017
# 5.01 2.5
# 4 received ('TIMEOUT', 3, True) from 4 at 1017
# 4.99 5.04
# 5 received ('TIMEOUT', 3, True) from 5 at 1017
# 5.0 5.04
# 6 received ('TIMEOUT', 3, True) from 6 at 1017
# 5.01 5.01
# 7 received ('TIMEOUT', 3, True) from 7 at 1017
# 5.04 4.97
# 8 received ('TIMEOUT', 3, True) from 8 at 1017
# 5.01 5.01
# 9 received ('TIMEOUT', 3, True) from 9 at 1017
# 5.01 5.01
# 3 received ('FLOW', (-0.5599901177282689, 5.006875802414598)) from 1 at 1018
# 6 received ('FLOW', (0.006875664339739629, 5.00687566433974)) from 3 at 1018
# 5 received ('FLOW', (0.9630143323036773, 5.041010052180752)) from 7 at 1018
# 0 received ('TIMEOUT', 3, True) from 0 at 1020
# 5.01 5.01
# 1 received ('TIMEOUT', 3, True) from 1 at 1020
# 5.01 5.01
# 2 received ('TIMEOUT', 3, True) from 2 at 1020
# 5.0 5.04
# 3 received ('TIMEOUT', 3, True) from 3 at 1020
# 5.01 2.5
# 4 received ('TIMEOUT', 3, True) from 4 at 1020
# 4.99 4.97
# 5 received ('TIMEOUT', 3, True) from 5 at 1020
# 5.0 5.01
# 6 received ('TIMEOUT', 3, True) from 6 at 1020
# 5.01 5.01
# 7 received ('TIMEOUT', 3, True) from 7 at 1020
# 5.04 5.1
# 8 received ('TIMEOUT', 3, True) from 8 at 1020
# 5.01 5.01
# 9 received ('TIMEOUT', 3, True) from 9 at 1020
# 5.01 5.01
# 6 received ('FLOW', (0.0068757333771678475, 5.006875733377168)) from 3 at 1021
# 5 received ('FLOW', (0.9630143323036773, 5.041010052180752)) from 7 at 1021
# 0 received ('TIMEOUT', 3, True) from 0 at 1023
# 5.01 5.04
# 1 received ('TIMEOUT', 3, True) from 1 at 1023
# 5.01 4.97
# 2 received ('TIMEOUT', 3, True) from 2 at 1023
# 5.0 5.04
# 3 received ('TIMEOUT', 3, True) from 3 at 1023
# 5.01 2.5
# 4 received ('TIMEOUT', 3, True) from 4 at 1023
# 4.99 5.04
# 5 received ('TIMEOUT', 3, True) from 5 at 1023
# 5.0 5.04
# 6 received ('TIMEOUT', 3, True) from 6 at 1023
# 5.01 5.01
# 7 received ('TIMEOUT', 3, True) from 7 at 1023
# 5.04 5.1
# 8 received ('TIMEOUT', 3, True) from 8 at 1023
# 5.01 5.01
# 9 received ('TIMEOUT', 3, True) from 9 at 1023
# 5.01 5.01
# 6 received ('FLOW', (0.0068757333771678475, 5.006875733377168)) from 3 at 1024
# 4 received ('FLOW', (-1.7168372535987597, 5.041010052180752)) from 7 at 1024
# 0 received ('TIMEOUT', 3, True) from 0 at 1026
# 5.01 4.98
# 1 received ('TIMEOUT', 3, True) from 1 at 1026
# 5.01 4.97
# 2 received ('TIMEOUT', 3, True) from 2 at 1026
# 5.0 5.01
# 3 received ('TIMEOUT', 3, True) from 3 at 1026
# 5.01 2.5
# 4 received ('TIMEOUT', 3, True) from 4 at 1026
# 4.99 5.04
# 5 received ('TIMEOUT', 3, True) from 5 at 1026
# 5.0 5.01
# 6 received ('TIMEOUT', 3, True) from 6 at 1026
# 5.01 5.01
# 7 received ('TIMEOUT', 3, True) from 7 at 1026
# 5.04 5.04
# 8 received ('TIMEOUT', 3, True) from 8 at 1026
# 5.01 5.1
# 9 received ('TIMEOUT', 3, True) from 9 at 1026
# 5.01 5.01
# 1 received ('FLOW', (0.5599900486908389, 5.006875733377168)) from 3 at 1027
# 1 received ('FLOW', (1.0062604579953218, 5.006875956841557)) from 8 at 1027
# 0 received ('TIMEOUT', 3, True) from 0 at 1029
# 5.01 4.98
# 1 received ('TIMEOUT', 3, True) from 1 at 1029
# 5.01 2.5
# 2 received ('TIMEOUT', 3, True) from 2 at 1029
# 5.0 5.01
# 3 received ('TIMEOUT', 3, True) from 3 at 1029
# 5.01 5.01
# 4 received ('TIMEOUT', 3, True) from 4 at 1029
# 4.99 5.04
# 5 received ('TIMEOUT', 3, True) from 5 at 1029
# 5.0 5.01
# 6 received ('TIMEOUT', 3, True) from 6 at 1029
# 5.01 5.01
# 7 received ('TIMEOUT', 3, True) from 7 at 1029
# 5.04 5.04
# 8 received ('TIMEOUT', 3, True) from 8 at 1029
# 5.01 5.01
# 9 received ('TIMEOUT', 3, True) from 9 at 1029
# 5.01 5.01
# 8 received ('FLOW', (-1.0062606400372536, 5.006875774799625)) from 1 at 1030
# 0 received ('TIMEOUT', 3, True) from 0 at 1032
# 5.01
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-263240bbee7e> in <module>
# ----> 1 main()
#
# <ipython-input-27-bbabaaa71a73> in main()
#      14         vcp = -1  # view-change periodicity - every vcp seconds, the set of neighbors change
#      15         sim = Simulator(nodes, distances, fp, vcp, timeout)
# ---> 16         x, y = sim.start()
#      17         messages_sent += x
#      18         rounds += y
#
# <ipython-input-49-5783c7a29ba0> in start(self)
#      18             hq.heappush(self.pending, (self.viewChange, (float("+infinity"), None, "VIEWCHANGE")))
#      19
# ---> 20         return self.runLoop()
#      21
#      22     def runLoop(self):
#
# <ipython-input-49-5783c7a29ba0> in runLoop(self)
#      51
#      52             # Message between two nodes or a timeout
# ---> 53             newEvents = self.nodes[dest].handle(src, msg)
#      54
#      55             if newEvents:
#
# <ipython-input-61-65c6af28f89d> in handle(self, src, msg)
#      57                 self.messages.append((src, msg[1]))
#      58             else: # timeout message, end of round
# ---> 59                 if not self.state_transition():
#      60                     return self.gen_message()
#      61                 else:
#
# <ipython-input-61-65c6af28f89d> in state_transition(self)
#      37
#      38         newE = self.calculateEstimate()
# ---> 39         print(round(newE, 2), round(self.e[self.k], 2))
#      40
#      41         stop = False
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # newlines imply flush in subprocesses
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# ~/anaconda3/lib/python3.7/site-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     398                                  copy_threshold=self.copy_threshold)
#     399             data.group = group
# --> 400         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     401
#     402     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~/anaconda3/lib/python3.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
